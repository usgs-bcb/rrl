# %% [markdown]
# This notebook explores using content negotiation from the overall DOI registration process across registration agents to retrieve basic metadata where we have links. We'll also try this with other types of links recorded as part of registering research references to see what all might be possible with this basic approach.

# %%
import requests
from IPython.display import display
from bis2 import dd
from bis import rrl

# %%
bis = dd.getDB("bis")
collection_rrl = bis["RRL"]

# %% [markdown]
# # Notes
# I ended up putting all of the very simple logic for this into a function in the rrl module of the bis package. I found that most if not all of the information coming back from content negotiation on DOI links is potentially useful. It does provide everything needed to pull out the citation parts and dig for further information. DOIs issued by CrossRef, in particular, have a ton of useful stuff, including all of the references from a publication in some instances. It may be that what we get from DOI content negotiation in those cases is sufficient and no further CrossRef search will be needed.
#
# I did find some odd cases where we have a DOI link that does appropriately de-reference to a URL for a landing page (particularly to FigShare) but the structured information returned through content negotiation on the original link does not have any metadata to speak of (e.g., not even a title). When I go resolve those and get to the landing page, I found a different DOI for the publication. We'll have to explore this further to see if there's a way to retrieve the "correct" DOI reference for these cases.

# %%
count = 0
recordToCheck = {}
while recordToCheck is not None:
    recordToCheck = collection_rrl.find_one({"$and":[{"url":{"$exists":True}},{"Link Metadata":{"$exists":False}}]})
    
    if recordToCheck is not None:
        count = count + 1
        print (count, collection_rrl.update_one({"_id":recordToCheck["_id"]},{"$set":{"Link Metadata":rrl.ResearchReferenceLibrary.ref_link_data(recordToCheck["url"])}}))
# Out:
# 1 <pymongo.results.UpdateResult object at 0x1042255e8>
# 2 <pymongo.results.UpdateResult object at 0x10390a090>
# 3 <pymongo.results.UpdateResult object at 0x1038f6ea0>
# 4 <pymongo.results.UpdateResult object at 0x1038f63a8>
# 5 <pymongo.results.UpdateResult object at 0x10319eaf8>
# 6 <pymongo.results.UpdateResult object at 0x1035d2f78>
# 7 <pymongo.results.UpdateResult object at 0x103958480>
# 8 <pymongo.results.UpdateResult object at 0x104225630>
# 9 <pymongo.results.UpdateResult object at 0x10420a708>
# 10 <pymongo.results.UpdateResult object at 0x1038f6f78>
# 11 <pymongo.results.UpdateResult object at 0x10390aab0>
# 12 <pymongo.results.UpdateResult object at 0x1038f6990>
# 13 <pymongo.results.UpdateResult object at 0x10420af78>
# 14 <pymongo.results.UpdateResult object at 0x10420a870>
# 15 <pymongo.results.UpdateResult object at 0x103049c60>
# 16 <pymongo.results.UpdateResult object at 0x10420a900>
# 17 <pymongo.results.UpdateResult object at 0x10399dea0>
# 18 <pymongo.results.UpdateResult object at 0x10399dee8>
# 19 <pymongo.results.UpdateResult object at 0x10399dd80>
# 20 <pymongo.results.UpdateResult object at 0x104213ab0>
# 21 <pymongo.results.UpdateResult object at 0x10424e4c8>
# 22 <pymongo.results.UpdateResult object at 0x103997ca8>
# 23 <pymongo.results.UpdateResult object at 0x104213510>
# 24 <pymongo.results.UpdateResult object at 0x1038f6d38>
# 25 <pymongo.results.UpdateResult object at 0x104262750>
# 26 <pymongo.results.UpdateResult object at 0x104262678>
# 27 <pymongo.results.UpdateResult object at 0x103997a20>
# 28 <pymongo.results.UpdateResult object at 0x10399dfc0>
# 29 <pymongo.results.UpdateResult object at 0x10399dab0>
# 30 <pymongo.results.UpdateResult object at 0x1039086c0>
# 31 <pymongo.results.UpdateResult object at 0x1038ff360>
# 32 <pymongo.results.UpdateResult object at 0x1038ff5a0>
# 33 <pymongo.results.UpdateResult object at 0x10424e0d8>
# 34 <pymongo.results.UpdateResult object at 0x1038f6f30>
# 35 <pymongo.results.UpdateResult object at 0x10420ae10>
# 36 <pymongo.results.UpdateResult object at 0x103908c18>
# 37 <pymongo.results.UpdateResult object at 0x10424ef78>
# 38 <pymongo.results.UpdateResult object at 0x10420aa20>
# 39 <pymongo.results.UpdateResult object at 0x10420abd0>
# 40 <pymongo.results.UpdateResult object at 0x10420a630>
# 41 <pymongo.results.UpdateResult object at 0x10420a990>
# 42 <pymongo.results.UpdateResult object at 0x10424e1b0>
# 43 <pymongo.results.UpdateResult object at 0x1038f6480>
# 44 <pymongo.results.UpdateResult object at 0x104225828>
# 45 <pymongo.results.UpdateResult object at 0x104225708>
# 46 <pymongo.results.UpdateResult object at 0x10424ea20>
# 47 <pymongo.results.UpdateResult object at 0x104213288>
# 48 <pymongo.results.UpdateResult object at 0x10420afc0>
# 49 <pymongo.results.UpdateResult object at 0x10420a8b8>
# 50 <pymongo.results.UpdateResult object at 0x1038f6a20>
# 51 <pymongo.results.UpdateResult object at 0x1038ff558>
# 52 <pymongo.results.UpdateResult object at 0x103997288>
# 53 <pymongo.results.UpdateResult object at 0x10399df78>
# 54 <pymongo.results.UpdateResult object at 0x10399da68>
# 55 <pymongo.results.UpdateResult object at 0x104262dc8>
# 56 <pymongo.results.UpdateResult object at 0x10399d798>
# 57 <pymongo.results.UpdateResult object at 0x1038f6dc8>
# 58 <pymongo.results.UpdateResult object at 0x104262870>
# 59 <pymongo.results.UpdateResult object at 0x10399df78>
# 60 <pymongo.results.UpdateResult object at 0x104225948>
# 61 <pymongo.results.UpdateResult object at 0x103908e10>
# 62 <pymongo.results.UpdateResult object at 0x10390a090>
# 63 <pymongo.results.UpdateResult object at 0x104225e10>
# 64 <pymongo.results.UpdateResult object at 0x10399db88>
# 65 <pymongo.results.UpdateResult object at 0x10390a558>
# 66 <pymongo.results.UpdateResult object at 0x10424eca8>
# 67 <pymongo.results.UpdateResult object at 0x104243120>
# 68 <pymongo.results.UpdateResult object at 0x104262558>
# 69 <pymongo.results.UpdateResult object at 0x10420aaf8>
# 70 <pymongo.results.UpdateResult object at 0x10390ab88>
# 71 <pymongo.results.UpdateResult object at 0x104243708>
# 72 <pymongo.results.UpdateResult object at 0x104213c60>
# 73 <pymongo.results.UpdateResult object at 0x10420aee8>
# 74 <pymongo.results.UpdateResult object at 0x10390aa20>
# 75 <pymongo.results.UpdateResult object at 0x104242288>
# 76 <pymongo.results.UpdateResult object at 0x10420ac60>
# 77 <pymongo.results.UpdateResult object at 0x10420a678>
# 78 <pymongo.results.UpdateResult object at 0x1042132d0>
# 79 <pymongo.results.UpdateResult object at 0x1039977e0>
# 80 <pymongo.results.UpdateResult object at 0x104241510>
# 81 <pymongo.results.UpdateResult object at 0x104241b40>
# 82 <pymongo.results.UpdateResult object at 0x1039974c8>
# 83 <pymongo.results.UpdateResult object at 0x1038ff438>
# 84 <pymongo.results.UpdateResult object at 0x1038ff1b0>
# 85 <pymongo.results.UpdateResult object at 0x10390ad80>
# 86 <pymongo.results.UpdateResult object at 0x1038f6ab0>
# 87 <pymongo.results.UpdateResult object at 0x103908288>
# 88 <pymongo.results.UpdateResult object at 0x103908120>
# 89 <pymongo.results.UpdateResult object at 0x104243870>
# 90 <pymongo.results.UpdateResult object at 0x1042435a0>
# 91 <pymongo.results.UpdateResult object at 0x1038ff8b8>
# 92 <pymongo.results.UpdateResult object at 0x1042426c0>
# 93 <pymongo.results.UpdateResult object at 0x104225120>
# 94 <pymongo.results.UpdateResult object at 0x1042250d8>
# 95 <pymongo.results.UpdateResult object at 0x10390aaf8>
# 96 <pymongo.results.UpdateResult object at 0x104241318>
# 97 <pymongo.results.UpdateResult object at 0x104242240>
# 98 <pymongo.results.UpdateResult object at 0x1042131b0>
# 99 <pymongo.results.UpdateResult object at 0x104213798>
# 100 <pymongo.results.UpdateResult object at 0x10390ad80>
# 101 <pymongo.results.UpdateResult object at 0x1042257e0>
# 102 <pymongo.results.UpdateResult object at 0x104225678>
# 103 <pymongo.results.UpdateResult object at 0x1039044c8>
# 104 <pymongo.results.UpdateResult object at 0x104213120>
# 105 <pymongo.results.UpdateResult object at 0x104213e58>
# 106 <pymongo.results.UpdateResult object at 0x104225090>
# 107 <pymongo.results.UpdateResult object at 0x104242ee8>
# 108 <pymongo.results.UpdateResult object at 0x103997c18>
# 109 <pymongo.results.UpdateResult object at 0x1042135a0>
# 110 <pymongo.results.UpdateResult object at 0x104225fc0>
# 111 <pymongo.results.UpdateResult object at 0x1038ff708>
# 112 <pymongo.results.UpdateResult object at 0x103904ea0>
# 113 <pymongo.results.UpdateResult object at 0x104213708>
# 114 <pymongo.results.UpdateResult object at 0x104213240>
# 115 <pymongo.results.UpdateResult object at 0x1038ff510>
# 116 <pymongo.results.UpdateResult object at 0x10390ab40>
# 117 <pymongo.results.UpdateResult object at 0x1039975a0>
# 118 <pymongo.results.UpdateResult object at 0x104225c60>
# 119 <pymongo.results.UpdateResult object at 0x1038f6e58>
# 120 <pymongo.results.UpdateResult object at 0x1038f6708>
# 121 <pymongo.results.UpdateResult object at 0x1042136c0>
# 122 <pymongo.results.UpdateResult object at 0x1038ffe58>
# 123 <pymongo.results.UpdateResult object at 0x104225900>
# 124 <pymongo.results.UpdateResult object at 0x103908708>
# 125 <pymongo.results.UpdateResult object at 0x104225d38>
# 126 <pymongo.results.UpdateResult object at 0x10424e048>
# 127 <pymongo.results.UpdateResult object at 0x103997af8>
# 128 <pymongo.results.UpdateResult object at 0x103904438>
# 129 <pymongo.results.UpdateResult object at 0x1038ff3a8>
# 130 <pymongo.results.UpdateResult object at 0x104262a68>
# 131 <pymongo.results.UpdateResult object at 0x1038f63f0>
# 132 <pymongo.results.UpdateResult object at 0x1038f63f0>
# 133 <pymongo.results.UpdateResult object at 0x1038f6480>
# 134 <pymongo.results.UpdateResult object at 0x103997dc8>
# 135 <pymongo.results.UpdateResult object at 0x104262f78>
# 136 <pymongo.results.UpdateResult object at 0x104262708>
# 137 <pymongo.results.UpdateResult object at 0x104241c18>
# 138 <pymongo.results.UpdateResult object at 0x1039081b0>
# 139 <pymongo.results.UpdateResult object at 0x103904a20>
# 140 <pymongo.results.UpdateResult object at 0x104225360>
# 141 <pymongo.results.UpdateResult object at 0x10399da20>
# 142 <pymongo.results.UpdateResult object at 0x1042415e8>
# 143 <pymongo.results.UpdateResult object at 0x104243870>
# 144 <pymongo.results.UpdateResult object at 0x103908fc0>
# 145 <pymongo.results.UpdateResult object at 0x104213dc8>
# 146 <pymongo.results.UpdateResult object at 0x104262cf0>
# 147 <pymongo.results.UpdateResult object at 0x103997f30>
# 148 <pymongo.results.UpdateResult object at 0x1042437e0>
# 149 <pymongo.results.UpdateResult object at 0x10399daf8>
# 150 <pymongo.results.UpdateResult object at 0x1038ffdc8>
# 151 <pymongo.results.UpdateResult object at 0x104225af8>
# 152 <pymongo.results.UpdateResult object at 0x1038ffaf8>
# 153 <pymongo.results.UpdateResult object at 0x103997630>
# 154 <pymongo.results.UpdateResult object at 0x103904120>
# 155 <pymongo.results.UpdateResult object at 0x103904e10>
# 156 <pymongo.results.UpdateResult object at 0x104242360>
# 157 <pymongo.results.UpdateResult object at 0x103904e10>
# 158 <pymongo.results.UpdateResult object at 0x10399daf8>
# 159 <pymongo.results.UpdateResult object at 0x10399de10>
# 160 <pymongo.results.UpdateResult object at 0x103997990>
# 161 <pymongo.results.UpdateResult object at 0x10424e0d8>
# 162 <pymongo.results.UpdateResult object at 0x10399df78>
# 163 <pymongo.results.UpdateResult object at 0x10399dd38>
# 164 <pymongo.results.UpdateResult object at 0x103997a20>
# 165 <pymongo.results.UpdateResult object at 0x10399ddc8>
# 166 <pymongo.results.UpdateResult object at 0x1039045a0>
# 167 <pymongo.results.UpdateResult object at 0x1042413f0>
# 168 <pymongo.results.UpdateResult object at 0x10399dee8>
# 169 <pymongo.results.UpdateResult object at 0x10399dc60>
# 170 <pymongo.results.UpdateResult object at 0x10399ddc8>
# 171 <pymongo.results.UpdateResult object at 0x103908ea0>
# 172 <pymongo.results.UpdateResult object at 0x103908b88>
# 173 <pymongo.results.UpdateResult object at 0x104243bd0>
# 174 <pymongo.results.UpdateResult object at 0x103997288>
# 175 <pymongo.results.UpdateResult object at 0x104213480>
# 176 <pymongo.results.UpdateResult object at 0x103904630>
# 177 <pymongo.results.UpdateResult object at 0x103904630>
# 178 <pymongo.results.UpdateResult object at 0x1039046c0>
# 179 <pymongo.results.UpdateResult object at 0x104213bd0>
# 180 <pymongo.results.UpdateResult object at 0x103904168>
# 181 <pymongo.results.UpdateResult object at 0x103904ca8>
# 182 <pymongo.results.UpdateResult object at 0x103904e58>
# 183 <pymongo.results.UpdateResult object at 0x104213480>
# 184 <pymongo.results.UpdateResult object at 0x10424e120>
# 185 <pymongo.results.UpdateResult object at 0x10424e480>
# 186 <pymongo.results.UpdateResult object at 0x10424ed38>
# 187 <pymongo.results.UpdateResult object at 0x104213c18>
# 188 <pymongo.results.UpdateResult object at 0x104213c18>
# 189 <pymongo.results.UpdateResult object at 0x1042139d8>
# 190 <pymongo.results.UpdateResult object at 0x1039083a8>
# 191 <pymongo.results.UpdateResult object at 0x1042134c8>
# 192 <pymongo.results.UpdateResult object at 0x104213510>
# 193 <pymongo.results.UpdateResult object at 0x1038ff9d8>
# 194 <pymongo.results.UpdateResult object at 0x10424e090>
# 195 <pymongo.results.UpdateResult object at 0x104213288>
# 196 <pymongo.results.UpdateResult object at 0x10424e798>
# 197 <pymongo.results.UpdateResult object at 0x10424e828>
# 198 <pymongo.results.UpdateResult object at 0x1038ff8b8>
# 199 <pymongo.results.UpdateResult object at 0x1038ffb88>
# 200 <pymongo.results.UpdateResult object at 0x10424e7e0>
# 201 <pymongo.results.UpdateResult object at 0x103997678>
# 202 <pymongo.results.UpdateResult object at 0x103997870>
# 203 <pymongo.results.UpdateResult object at 0x1042137e0>
# 204 <pymongo.results.UpdateResult object at 0x1042137e0>
# 205 <pymongo.results.UpdateResult object at 0x104213318>
# 206 <pymongo.results.UpdateResult object at 0x104213e10>
# 207 <pymongo.results.UpdateResult object at 0x104213990>
# 208 <pymongo.results.UpdateResult object at 0x1038ffc18>
# 209 <pymongo.results.UpdateResult object at 0x1038ff1b0>
# 210 <pymongo.results.UpdateResult object at 0x103908360>
# 211 <pymongo.results.UpdateResult object at 0x1039086c0>
# 212 <pymongo.results.UpdateResult object at 0x104213cf0>
# 213 <pymongo.results.UpdateResult object at 0x1039085e8>
# 214 <pymongo.results.UpdateResult object at 0x10424e090>
# 215 <pymongo.results.UpdateResult object at 0x1039088b8>
# 216 <pymongo.results.UpdateResult object at 0x104213678>
# 217 <pymongo.results.UpdateResult object at 0x1038ffee8>
# 218 <pymongo.results.UpdateResult object at 0x103997d38>
# 219 <pymongo.results.UpdateResult object at 0x103904ab0>
# 220 <pymongo.results.UpdateResult object at 0x104241090>
# 221 <pymongo.results.UpdateResult object at 0x104213af8>
# 222 <pymongo.results.UpdateResult object at 0x103904480>
# 223 <pymongo.results.UpdateResult object at 0x104213c60>
# 224 <pymongo.results.UpdateResult object at 0x104213750>
# 225 <pymongo.results.UpdateResult object at 0x104213d38>
# 226 <pymongo.results.UpdateResult object at 0x104213510>
# 227 <pymongo.results.UpdateResult object at 0x104213f30>
# 228 <pymongo.results.UpdateResult object at 0x104213f30>
# 229 <pymongo.results.UpdateResult object at 0x104213f30>
# 230 <pymongo.results.UpdateResult object at 0x104213af8>
# 231 <pymongo.results.UpdateResult object at 0x104213d38>
# 232 <pymongo.results.UpdateResult object at 0x1038ffee8>
# 233 <pymongo.results.UpdateResult object at 0x103904558>
# 234 <pymongo.results.UpdateResult object at 0x1042139d8>
# 235 <pymongo.results.UpdateResult object at 0x104213fc0>
# 236 <pymongo.results.UpdateResult object at 0x1042139d8>
# 237 <pymongo.results.UpdateResult object at 0x104213708>
# 238 <pymongo.results.UpdateResult object at 0x104242e58>
# 239 <pymongo.results.UpdateResult object at 0x10424e870>
# 240 <pymongo.results.UpdateResult object at 0x104213a68>
# 241 <pymongo.results.UpdateResult object at 0x10424e5e8>
# 242 <pymongo.results.UpdateResult object at 0x10424e9d8>
# 243 <pymongo.results.UpdateResult object at 0x1039040d8>
# 244 <pymongo.results.UpdateResult object at 0x104213bd0>
# 245 <pymongo.results.UpdateResult object at 0x1042133f0>
# 246 <pymongo.results.UpdateResult object at 0x1038ff510>
# 247 <pymongo.results.UpdateResult object at 0x10424eb40>
# 248 <pymongo.results.UpdateResult object at 0x10424eaf8>
# 249 <pymongo.results.UpdateResult object at 0x103997e10>
# 250 <pymongo.results.UpdateResult object at 0x103997870>
# 251 <pymongo.results.UpdateResult object at 0x1042629d8>
# 252 <pymongo.results.UpdateResult object at 0x104225c60>
# 253 <pymongo.results.UpdateResult object at 0x104213ee8>
# 254 <pymongo.results.UpdateResult object at 0x104225798>
# 255 <pymongo.results.UpdateResult object at 0x1038ff2d0>
# 256 <pymongo.results.UpdateResult object at 0x104225510>
# 257 <pymongo.results.UpdateResult object at 0x1038ff828>
# 258 <pymongo.results.UpdateResult object at 0x103904870>
# 259 <pymongo.results.UpdateResult object at 0x103997480>
# 260 <pymongo.results.UpdateResult object at 0x104242b88>
# 261 <pymongo.results.UpdateResult object at 0x10424e318>
# 262 <pymongo.results.UpdateResult object at 0x1038ffe10>
# 263 <pymongo.results.UpdateResult object at 0x10424e630>
# 264 <pymongo.results.UpdateResult object at 0x1038ff630>
# 265 <pymongo.results.UpdateResult object at 0x1038ffe58>
# 266 <pymongo.results.UpdateResult object at 0x1038ffdc8>
# 267 <pymongo.results.UpdateResult object at 0x1038ff318>
# 268 <pymongo.results.UpdateResult object at 0x1038ffd80>
# 269 <pymongo.results.UpdateResult object at 0x1038ff048>
# 270 <pymongo.results.UpdateResult object at 0x1042410d8>
# 271 <pymongo.results.UpdateResult object at 0x1038ffd80>
# 272 <pymongo.results.UpdateResult object at 0x10424e900>
# 273 <pymongo.results.UpdateResult object at 0x10424e6c0>
# 274 <pymongo.results.UpdateResult object at 0x1038ff630>
# 275 <pymongo.results.UpdateResult object at 0x1038ff1f8>
# 276 <pymongo.results.UpdateResult object at 0x1038ff828>
# 277 <pymongo.results.UpdateResult object at 0x104225d80>
# 278 <pymongo.results.UpdateResult object at 0x1038ff048>
# 279 <pymongo.results.UpdateResult object at 0x103997288>
# 280 <pymongo.results.UpdateResult object at 0x1038ff828>
# 281 <pymongo.results.UpdateResult object at 0x1038ff828>
# 282 <pymongo.results.UpdateResult object at 0x1042422d0>
# 283 <pymongo.results.UpdateResult object at 0x103904bd0>
# 284 <pymongo.results.UpdateResult object at 0x103908750>
# 285 <pymongo.results.UpdateResult object at 0x103904b88>
# 286 <pymongo.results.UpdateResult object at 0x104225d38>
# 287 <pymongo.results.UpdateResult object at 0x1039976c0>
# 288 <pymongo.results.UpdateResult object at 0x1038ff828>
# 289 <pymongo.results.UpdateResult object at 0x1038ff828>
# 290 <pymongo.results.UpdateResult object at 0x1038ff828>
# 291 <pymongo.results.UpdateResult object at 0x104225678>
# 292 <pymongo.results.UpdateResult object at 0x104241b88>
# 293 <pymongo.results.UpdateResult object at 0x1038ff2d0>
# 294 <pymongo.results.UpdateResult object at 0x1039043a8>
# 295 <pymongo.results.UpdateResult object at 0x103908828>
# 296 <pymongo.results.UpdateResult object at 0x1039087e0>
# 297 <pymongo.results.UpdateResult object at 0x1038ffe10>
# 298 <pymongo.results.UpdateResult object at 0x1042416c0>
# 299 <pymongo.results.UpdateResult object at 0x1042416c0>
# 300 <pymongo.results.UpdateResult object at 0x1039041f8>
# 301 <pymongo.results.UpdateResult object at 0x1039043f0>
# 302 <pymongo.results.UpdateResult object at 0x103904048>
# 303 <pymongo.results.UpdateResult object at 0x103904048>
# 304 <pymongo.results.UpdateResult object at 0x104241fc0>
# 305 <pymongo.results.UpdateResult object at 0x104242678>
# 306 <pymongo.results.UpdateResult object at 0x103997f78>
# 307 <pymongo.results.UpdateResult object at 0x104242ca8>
# 308 <pymongo.results.UpdateResult object at 0x103997750>
# 309 <pymongo.results.UpdateResult object at 0x103997750>
# 310 <pymongo.results.UpdateResult object at 0x103908e10>
# 311 <pymongo.results.UpdateResult object at 0x1039081b0>
# 312 <pymongo.results.UpdateResult object at 0x103908b40>
# 313 <pymongo.results.UpdateResult object at 0x1038ffcf0>
# 314 <pymongo.results.UpdateResult object at 0x1038ff438>
# 315 <pymongo.results.UpdateResult object at 0x1038ff3f0>
# 316 <pymongo.results.UpdateResult object at 0x10424eb88>
# 317 <pymongo.results.UpdateResult object at 0x1039043a8>
# 318 <pymongo.results.UpdateResult object at 0x103908090>
# 319 <pymongo.results.UpdateResult object at 0x103997ee8>
# 320 <pymongo.results.UpdateResult object at 0x1042132d0>
# 321 <pymongo.results.UpdateResult object at 0x1042132d0>
# 322 <pymongo.results.UpdateResult object at 0x1042132d0>
# 323 <pymongo.results.UpdateResult object at 0x104241630>
# 324 <pymongo.results.UpdateResult object at 0x104213ca8>
# 325 <pymongo.results.UpdateResult object at 0x104213ca8>
# 326 <pymongo.results.UpdateResult object at 0x103997b88>
# 327 <pymongo.results.UpdateResult object at 0x1039043f0>
# 328 <pymongo.results.UpdateResult object at 0x104213ca8>
# 329 <pymongo.results.UpdateResult object at 0x103904090>
# 330 <pymongo.results.UpdateResult object at 0x1039082d0>
# 331 <pymongo.results.UpdateResult object at 0x104213ca8>
# 332 <pymongo.results.UpdateResult object at 0x104213ca8>
# 333 <pymongo.results.UpdateResult object at 0x104213ca8>
# 334 <pymongo.results.UpdateResult object at 0x104213ca8>
# 335 <pymongo.results.UpdateResult object at 0x104213ca8>
# 336 <pymongo.results.UpdateResult object at 0x104213ca8>
# 337 <pymongo.results.UpdateResult object at 0x104213ca8>
# 338 <pymongo.results.UpdateResult object at 0x104213ca8>
# 339 <pymongo.results.UpdateResult object at 0x104213ca8>
# 340 <pymongo.results.UpdateResult object at 0x103997a20>
# 341 <pymongo.results.UpdateResult object at 0x103908678>
# 342 <pymongo.results.UpdateResult object at 0x103904b40>
# 343 <pymongo.results.UpdateResult object at 0x103997bd0>
# 344 <pymongo.results.UpdateResult object at 0x103904b40>
# 345 <pymongo.results.UpdateResult object at 0x103904b40>
# 346 <pymongo.results.UpdateResult object at 0x1042416c0>
# 347 <pymongo.results.UpdateResult object at 0x103904b40>
# 348 <pymongo.results.UpdateResult object at 0x1042132d0>
# 349 <pymongo.results.UpdateResult object at 0x1042132d0>
# 350 <pymongo.results.UpdateResult object at 0x1042132d0>
# 351 <pymongo.results.UpdateResult object at 0x1042132d0>
# 352 <pymongo.results.UpdateResult object at 0x1042132d0>
# 353 <pymongo.results.UpdateResult object at 0x1042132d0>
# 354 <pymongo.results.UpdateResult object at 0x1042132d0>
# 355 <pymongo.results.UpdateResult object at 0x1042132d0>
# 356 <pymongo.results.UpdateResult object at 0x10424e090>
# 357 <pymongo.results.UpdateResult object at 0x1039043a8>
# 358 <pymongo.results.UpdateResult object at 0x104213ca8>
# 359 <pymongo.results.UpdateResult object at 0x1039084c8>
# 360 <pymongo.results.UpdateResult object at 0x103997d38>
# 361 <pymongo.results.UpdateResult object at 0x103908b88>
# 362 <pymongo.results.UpdateResult object at 0x103904a20>
# 363 <pymongo.results.UpdateResult object at 0x1042132d0>
# 364 <pymongo.results.UpdateResult object at 0x1042132d0>
# 365 <pymongo.results.UpdateResult object at 0x104241870>
# 366 <pymongo.results.UpdateResult object at 0x104213ca8>
# 367 <pymongo.results.UpdateResult object at 0x104213ca8>
# 368 <pymongo.results.UpdateResult object at 0x1039084c8>
# 369 <pymongo.results.UpdateResult object at 0x10424edc8>
# 370 <pymongo.results.UpdateResult object at 0x1042132d0>
# 371 <pymongo.results.UpdateResult object at 0x1042132d0>
# 372 <pymongo.results.UpdateResult object at 0x1042132d0>
# 373 <pymongo.results.UpdateResult object at 0x1042132d0>
# 374 <pymongo.results.UpdateResult object at 0x1042132d0>
# 375 <pymongo.results.UpdateResult object at 0x1042132d0>
# 376 <pymongo.results.UpdateResult object at 0x104225a20>
# 377 <pymongo.results.UpdateResult object at 0x1039083f0>
# 378 <pymongo.results.UpdateResult object at 0x104225168>
# 379 <pymongo.results.UpdateResult object at 0x104241630>
# 380 <pymongo.results.UpdateResult object at 0x104225a68>
# 381 <pymongo.results.UpdateResult object at 0x104241750>
# 382 <pymongo.results.UpdateResult object at 0x104241ab0>
# 383 <pymongo.results.UpdateResult object at 0x104262360>
# 384 <pymongo.results.UpdateResult object at 0x104262360>
# 385 <pymongo.results.UpdateResult object at 0x104262b88>
# 386 <pymongo.results.UpdateResult object at 0x103997708>
# 387 <pymongo.results.UpdateResult object at 0x1039975a0>
# 388 <pymongo.results.UpdateResult object at 0x103904b88>
# 389 <pymongo.results.UpdateResult object at 0x104262048>
# 390 <pymongo.results.UpdateResult object at 0x103908ea0>
# 391 <pymongo.results.UpdateResult object at 0x103908870>
# 392 <pymongo.results.UpdateResult object at 0x103904c18>
# 393 <pymongo.results.UpdateResult object at 0x104241ab0>
# 394 <pymongo.results.UpdateResult object at 0x103904b88>
# 395 <pymongo.results.UpdateResult object at 0x103904090>
# 396 <pymongo.results.UpdateResult object at 0x103904240>
# 397 <pymongo.results.UpdateResult object at 0x104225828>
# 398 <pymongo.results.UpdateResult object at 0x1039085a0>
# 399 <pymongo.results.UpdateResult object at 0x1042419d8>
# 400 <pymongo.results.UpdateResult object at 0x103904b40>
# 401 <pymongo.results.UpdateResult object at 0x103904cf0>
# 402 <pymongo.results.UpdateResult object at 0x10424efc0>
# 403 <pymongo.results.UpdateResult object at 0x103904bd0>
# 404 <pymongo.results.UpdateResult object at 0x1039084c8>
# 405 <pymongo.results.UpdateResult object at 0x1039084c8>
# 406 <pymongo.results.UpdateResult object at 0x1039084c8>
# 407 <pymongo.results.UpdateResult object at 0x103904c18>
# 408 <pymongo.results.UpdateResult object at 0x1042430d8>
# 409 <pymongo.results.UpdateResult object at 0x103904ea0>
# 410 <pymongo.results.UpdateResult object at 0x104243318>
# 411 <pymongo.results.UpdateResult object at 0x103908870>
# 412 <pymongo.results.UpdateResult object at 0x1039081f8>
# 413 <pymongo.results.UpdateResult object at 0x1039086c0>
# 414 <pymongo.results.UpdateResult object at 0x103908750>
# 415 <pymongo.results.UpdateResult object at 0x1042256c0>
# 416 <pymongo.results.UpdateResult object at 0x103904c60>
# 417 <pymongo.results.UpdateResult object at 0x103908630>
# 418 <pymongo.results.UpdateResult object at 0x103904d38>
# 419 <pymongo.results.UpdateResult object at 0x103904240>
# 420 <pymongo.results.UpdateResult object at 0x104243ab0>
# 421 <pymongo.results.UpdateResult object at 0x104262fc0>
# 422 <pymongo.results.UpdateResult object at 0x1039974c8>
# 423 <pymongo.results.UpdateResult object at 0x1039044c8>
# 424 <pymongo.results.UpdateResult object at 0x1042627e0>
# 425 <pymongo.results.UpdateResult object at 0x104225a68>
# 426 <pymongo.results.UpdateResult object at 0x1042413f0>
# 427 <pymongo.results.UpdateResult object at 0x103904318>
# 428 <pymongo.results.UpdateResult object at 0x1039044c8>
# 429 <pymongo.results.UpdateResult object at 0x1039044c8>
# 430 <pymongo.results.UpdateResult object at 0x1039040d8>
# 431 <pymongo.results.UpdateResult object at 0x103904900>
# 432 <pymongo.results.UpdateResult object at 0x104225900>
# 433 <pymongo.results.UpdateResult object at 0x1039041f8>
# 434 <pymongo.results.UpdateResult object at 0x1039041f8>
# 435 <pymongo.results.UpdateResult object at 0x103904900>
# 436 <pymongo.results.UpdateResult object at 0x103904900>
# 437 <pymongo.results.UpdateResult object at 0x1039040d8>
# 438 <pymongo.results.UpdateResult object at 0x1039040d8>
# 439 <pymongo.results.UpdateResult object at 0x103997798>
# 440 <pymongo.results.UpdateResult object at 0x104262750>
# 441 <pymongo.results.UpdateResult object at 0x1039088b8>
# 442 <pymongo.results.UpdateResult object at 0x1042625a0>
# 443 <pymongo.results.UpdateResult object at 0x103904120>
# 444 <pymongo.results.UpdateResult object at 0x103997ee8>
# 445 <pymongo.results.UpdateResult object at 0x10424ee58>
# 446 <pymongo.results.UpdateResult object at 0x1039087e0>
# 447 <pymongo.results.UpdateResult object at 0x103908b40>
# 448 <pymongo.results.UpdateResult object at 0x104262af8>
# 449 <pymongo.results.UpdateResult object at 0x10427cdc8>
# 450 <pymongo.results.UpdateResult object at 0x10427c7e0>
# 451 <pymongo.results.UpdateResult object at 0x1042428b8>
# 452 <pymongo.results.UpdateResult object at 0x104262750>
# 453 <pymongo.results.UpdateResult object at 0x10425b798>
# 454 <pymongo.results.UpdateResult object at 0x103908798>
# 455 <pymongo.results.UpdateResult object at 0x1039976c0>
# 456 <pymongo.results.UpdateResult object at 0x10425b168>
# 457 <pymongo.results.UpdateResult object at 0x10425ba68>
# 458 <pymongo.results.UpdateResult object at 0x103997b40>
# 459 <pymongo.results.UpdateResult object at 0x104243120>
# 460 <pymongo.results.UpdateResult object at 0x10425bca8>
# 461 <pymongo.results.UpdateResult object at 0x1039081b0>
# 462 <pymongo.results.UpdateResult object at 0x104262af8>
# 463 <pymongo.results.UpdateResult object at 0x1042625e8>
# 464 <pymongo.results.UpdateResult object at 0x104262120>
# 465 <pymongo.results.UpdateResult object at 0x104262828>
# 466 <pymongo.results.UpdateResult object at 0x1042621b0>
# 467 <pymongo.results.UpdateResult object at 0x103997990>
# 468 <pymongo.results.UpdateResult object at 0x103997990>
# 469 <pymongo.results.UpdateResult object at 0x103997cf0>
# 470 <pymongo.results.UpdateResult object at 0x103997990>
# 471 <pymongo.results.UpdateResult object at 0x104262240>
# 472 <pymongo.results.UpdateResult object at 0x104262240>
# 473 <pymongo.results.UpdateResult object at 0x104241ab0>
# 474 <pymongo.results.UpdateResult object at 0x1042621b0>
# 475 <pymongo.results.UpdateResult object at 0x104241cf0>
# 476 <pymongo.results.UpdateResult object at 0x1039978b8>
# 477 <pymongo.results.UpdateResult object at 0x104262c60>
# 478 <pymongo.results.UpdateResult object at 0x1039978b8>
# 479 <pymongo.results.UpdateResult object at 0x104262c60>
# 480 <pymongo.results.UpdateResult object at 0x104262fc0>
# 481 <pymongo.results.UpdateResult object at 0x103997b88>
# 482 <pymongo.results.UpdateResult object at 0x104262798>
# 483 <pymongo.results.UpdateResult object at 0x104225360>
# 484 <pymongo.results.UpdateResult object at 0x104225360>
# 485 <pymongo.results.UpdateResult object at 0x10426d750>
# 486 <pymongo.results.UpdateResult object at 0x104262d38>
# 487 <pymongo.results.UpdateResult object at 0x104225bd0>
# 488 <pymongo.results.UpdateResult object at 0x1042624c8>
# 489 <pymongo.results.UpdateResult object at 0x1042256c0>
# 490 <pymongo.results.UpdateResult object at 0x103997b88>
# 491 <pymongo.results.UpdateResult object at 0x1042258b8>
# 492 <pymongo.results.UpdateResult object at 0x10427c120>
# 493 <pymongo.results.UpdateResult object at 0x10427ca68>
# 494 <pymongo.results.UpdateResult object at 0x104243d80>
# 495 <pymongo.results.UpdateResult object at 0x104262f30>
# 496 <pymongo.results.UpdateResult object at 0x104262d80>
# 497 <pymongo.results.UpdateResult object at 0x1042624c8>
# 498 <pymongo.results.UpdateResult object at 0x1042629d8>
# 499 <pymongo.results.UpdateResult object at 0x1039974c8>
# 500 <pymongo.results.UpdateResult object at 0x104262af8>
# 501 <pymongo.results.UpdateResult object at 0x103997ee8>
# 502 <pymongo.results.UpdateResult object at 0x104243f78>
# 503 <pymongo.results.UpdateResult object at 0x103997828>
# 504 <pymongo.results.UpdateResult object at 0x103997828>
# 505 <pymongo.results.UpdateResult object at 0x103997a20>
# 506 <pymongo.results.UpdateResult object at 0x103997828>
# 507 <pymongo.results.UpdateResult object at 0x103997828>
# 508 <pymongo.results.UpdateResult object at 0x10425b5a0>
# 509 <pymongo.results.UpdateResult object at 0x10425bf30>
# 510 <pymongo.results.UpdateResult object at 0x10426dee8>
# 511 <pymongo.results.UpdateResult object at 0x10427c240>
# 512 <pymongo.results.UpdateResult object at 0x10426d1b0>
# 513 <pymongo.results.UpdateResult object at 0x104243f30>
# 514 <pymongo.results.UpdateResult object at 0x1042251b0>
# 515 <pymongo.results.UpdateResult object at 0x103997a20>
# 516 <pymongo.results.UpdateResult object at 0x104225120>
# 517 <pymongo.results.UpdateResult object at 0x1042628b8>
# 518 <pymongo.results.UpdateResult object at 0x103908e10>
# 519 <pymongo.results.UpdateResult object at 0x103904240>
# 520 <pymongo.results.UpdateResult object at 0x1042414c8>
# 521 <pymongo.results.UpdateResult object at 0x104225558>
# 522 <pymongo.results.UpdateResult object at 0x104262bd0>
# 523 <pymongo.results.UpdateResult object at 0x104225240>
# 524 <pymongo.results.UpdateResult object at 0x1042420d8>
# 525 <pymongo.results.UpdateResult object at 0x103908ea0>
# 526 <pymongo.results.UpdateResult object at 0x104242a20>
# 527 <pymongo.results.UpdateResult object at 0x104242a20>
# 528 <pymongo.results.UpdateResult object at 0x103908b88>
# 529 <pymongo.results.UpdateResult object at 0x103908e10>
# 530 <pymongo.results.UpdateResult object at 0x104242048>
# 531 <pymongo.results.UpdateResult object at 0x1042623a8>
# 532 <pymongo.results.UpdateResult object at 0x103997288>
# 533 <pymongo.results.UpdateResult object at 0x1039975e8>
# 534 <pymongo.results.UpdateResult object at 0x104242c18>
# 535 <pymongo.results.UpdateResult object at 0x103997d80>
# 536 <pymongo.results.UpdateResult object at 0x10424edc8>
# 537 <pymongo.results.UpdateResult object at 0x104262dc8>
# 538 <pymongo.results.UpdateResult object at 0x103904c60>
# 539 <pymongo.results.UpdateResult object at 0x1042256c0>
# 540 <pymongo.results.UpdateResult object at 0x10424e8b8>
# 541 <pymongo.results.UpdateResult object at 0x103997900>
# 542 <pymongo.results.UpdateResult object at 0x103997900>
# 543 <pymongo.results.UpdateResult object at 0x104225630>
# 544 <pymongo.results.UpdateResult object at 0x10427c558>
# 545 <pymongo.results.UpdateResult object at 0x10426dd38>
# 546 <pymongo.results.UpdateResult object at 0x10424e090>
# 547 <pymongo.results.UpdateResult object at 0x103997f78>
# 548 <pymongo.results.UpdateResult object at 0x10427c360>
# 549 <pymongo.results.UpdateResult object at 0x10427c5e8>
# 550 <pymongo.results.UpdateResult object at 0x104225120>
# 551 <pymongo.results.UpdateResult object at 0x104225ab0>
# 552 <pymongo.results.UpdateResult object at 0x104225480>
# 553 <pymongo.results.UpdateResult object at 0x10424e2d0>
# 554 <pymongo.results.UpdateResult object at 0x1042251f8>
# 555 <pymongo.results.UpdateResult object at 0x104225cf0>
# 556 <pymongo.results.UpdateResult object at 0x104225e58>
# 557 <pymongo.results.UpdateResult object at 0x104225d38>
# 558 <pymongo.results.UpdateResult object at 0x104225120>
# 559 <pymongo.results.UpdateResult object at 0x104225948>
# 560 <pymongo.results.UpdateResult object at 0x104225558>
# 561 <pymongo.results.UpdateResult object at 0x1042622d0>
# 562 <pymongo.results.UpdateResult object at 0x104225630>
# 563 <pymongo.results.UpdateResult object at 0x10427c798>
# 564 <pymongo.results.UpdateResult object at 0x10424edc8>
# 565 <pymongo.results.UpdateResult object at 0x104246b88>
# 566 <pymongo.results.UpdateResult object at 0x104246120>
# 567 <pymongo.results.UpdateResult object at 0x1042250d8>
# 568 <pymongo.results.UpdateResult object at 0x104246480>
# 569 <pymongo.results.UpdateResult object at 0x104262af8>
# 570 <pymongo.results.UpdateResult object at 0x104225b40>
# 571 <pymongo.results.UpdateResult object at 0x104225ab0>
# 572 <pymongo.results.UpdateResult object at 0x10424e438>
# 573 <pymongo.results.UpdateResult object at 0x10424e750>
# 574 <pymongo.results.UpdateResult object at 0x1042259d8>
# 575 <pymongo.results.UpdateResult object at 0x1042259d8>
# 576 <pymongo.results.UpdateResult object at 0x1042259d8>
# 577 <pymongo.results.UpdateResult object at 0x104225990>
# 578 <pymongo.results.UpdateResult object at 0x104225990>
# 579 <pymongo.results.UpdateResult object at 0x10424e5a0>
# 580 <pymongo.results.UpdateResult object at 0x10424eea0>
# 581 <pymongo.results.UpdateResult object at 0x10425be10>
# 582 <pymongo.results.UpdateResult object at 0x104246fc0>
# 583 <pymongo.results.UpdateResult object at 0x104246048>
# 584 <pymongo.results.UpdateResult object at 0x10424e7e0>
# 585 <pymongo.results.UpdateResult object at 0x104262168>
# 586 <pymongo.results.UpdateResult object at 0x104262168>
# 587 <pymongo.results.UpdateResult object at 0x104225318>
# 588 <pymongo.results.UpdateResult object at 0x104225318>
# 589 <pymongo.results.UpdateResult object at 0x104225318>
# 590 <pymongo.results.UpdateResult object at 0x10426d900>
# 591 <pymongo.results.UpdateResult object at 0x104262288>
# 592 <pymongo.results.UpdateResult object at 0x1042461f8>
# 593 <pymongo.results.UpdateResult object at 0x10424e948>
# 594 <pymongo.results.UpdateResult object at 0x10424ea20>
# 595 <pymongo.results.UpdateResult object at 0x1042620d8>
# 596 <pymongo.results.UpdateResult object at 0x1042623a8>
# 597 <pymongo.results.UpdateResult object at 0x1042628b8>
# 598 <pymongo.results.UpdateResult object at 0x104241750>
# 599 <pymongo.results.UpdateResult object at 0x10425b750>
# 600 <pymongo.results.UpdateResult object at 0x10424e630>
# 601 <pymongo.results.UpdateResult object at 0x10424e318>
# 602 <pymongo.results.UpdateResult object at 0x104241708>
# 603 <pymongo.results.UpdateResult object at 0x10424e900>
# 604 <pymongo.results.UpdateResult object at 0x104246a68>
# 605 <pymongo.results.UpdateResult object at 0x10424e240>
# 606 <pymongo.results.UpdateResult object at 0x1042625a0>
# 607 <pymongo.results.UpdateResult object at 0x1042416c0>
# 608 <pymongo.results.UpdateResult object at 0x104262cf0>
# 609 <pymongo.results.UpdateResult object at 0x104262cf0>
# 610 <pymongo.results.UpdateResult object at 0x104262630>
# 611 <pymongo.results.UpdateResult object at 0x104262630>
# 612 <pymongo.results.UpdateResult object at 0x1042621f8>
# 613 <pymongo.results.UpdateResult object at 0x10424eab0>
# 614 <pymongo.results.UpdateResult object at 0x104241a68>
# 615 <pymongo.results.UpdateResult object at 0x104246870>
# 616 <pymongo.results.UpdateResult object at 0x104262510>
# 617 <pymongo.results.UpdateResult object at 0x10424e708>
# 618 <pymongo.results.UpdateResult object at 0x10424e360>
# 619 <pymongo.results.UpdateResult object at 0x1042467e0>
# 620 <pymongo.results.UpdateResult object at 0x10424e0d8>
# 621 <pymongo.results.UpdateResult object at 0x10424e870>
# 622 <pymongo.results.UpdateResult object at 0x10426dfc0>
# 623 <pymongo.results.UpdateResult object at 0x104262af8>
# 624 <pymongo.results.UpdateResult object at 0x104262e10>
# 625 <pymongo.results.UpdateResult object at 0x10424e9d8>
# 626 <pymongo.results.UpdateResult object at 0x10424e438>
# 627 <pymongo.results.UpdateResult object at 0x104246798>
# 628 <pymongo.results.UpdateResult object at 0x104262f30>
# 629 <pymongo.results.UpdateResult object at 0x10424ee58>
# 630 <pymongo.results.UpdateResult object at 0x10424e090>
# 631 <pymongo.results.UpdateResult object at 0x1042625e8>
# 632 <pymongo.results.UpdateResult object at 0x104262990>
# 633 <pymongo.results.UpdateResult object at 0x10424e288>
# 634 <pymongo.results.UpdateResult object at 0x104262b88>
# 635 <pymongo.results.UpdateResult object at 0x104241d80>
# 636 <pymongo.results.UpdateResult object at 0x104241d80>
# 637 <pymongo.results.UpdateResult object at 0x104262318>
# 638 <pymongo.results.UpdateResult object at 0x10424e048>
# 639 <pymongo.results.UpdateResult object at 0x10424e1f8>
# 640 <pymongo.results.UpdateResult object at 0x10426d9d8>
# 641 <pymongo.results.UpdateResult object at 0x10426da20>
# 642 <pymongo.results.UpdateResult object at 0x104262168>
# 643 <pymongo.results.UpdateResult object at 0x104262b88>
# 644 <pymongo.results.UpdateResult object at 0x10424eca8>
# 645 <pymongo.results.UpdateResult object at 0x10424eca8>
# 646 <pymongo.results.UpdateResult object at 0x10424eee8>
# 647 <pymongo.results.UpdateResult object at 0x104262f30>
# 648 <pymongo.results.UpdateResult object at 0x104241948>
# 649 <pymongo.results.UpdateResult object at 0x10424e900>
# 650 <pymongo.results.UpdateResult object at 0x104241360>
# 651 <pymongo.results.UpdateResult object at 0x10424e1f8>
# 652 <pymongo.results.UpdateResult object at 0x10424e2d0>
# 653 <pymongo.results.UpdateResult object at 0x1042622d0>
# 654 <pymongo.results.UpdateResult object at 0x104262b40>
# 655 <pymongo.results.UpdateResult object at 0x104262b40>
# 656 <pymongo.results.UpdateResult object at 0x1042462d0>
# 657 <pymongo.results.UpdateResult object at 0x1042469d8>
# 658 <pymongo.results.UpdateResult object at 0x104246240>
# 659 <pymongo.results.UpdateResult object at 0x10424e3a8>
# 660 <pymongo.results.UpdateResult object at 0x10424e3a8>
# 661 <pymongo.results.UpdateResult object at 0x1042622d0>
# 662 <pymongo.results.UpdateResult object at 0x10424ee10>
# 663 <pymongo.results.UpdateResult object at 0x10424e900>
# 664 <pymongo.results.UpdateResult object at 0x10426d948>
# 665 <pymongo.results.UpdateResult object at 0x104243b88>
# 666 <pymongo.results.UpdateResult object at 0x10427cdc8>
# 667 <pymongo.results.UpdateResult object at 0x10426d5e8>
# 668 <pymongo.results.UpdateResult object at 0x10426dd80>
# 669 <pymongo.results.UpdateResult object at 0x104241438>
# 670 <pymongo.results.UpdateResult object at 0x104241438>
# 671 <pymongo.results.UpdateResult object at 0x1042413f0>
# 672 <pymongo.results.UpdateResult object at 0x10426d630>
# 673 <pymongo.results.UpdateResult object at 0x10426d948>
# 674 <pymongo.results.UpdateResult object at 0x10424e8b8>
# 675 <pymongo.results.UpdateResult object at 0x10424e2d0>
# 676 <pymongo.results.UpdateResult object at 0x104262e58>
# 677 <pymongo.results.UpdateResult object at 0x10425bfc0>
# 678 <pymongo.results.UpdateResult object at 0x10427c0d8>
# 679 <pymongo.results.UpdateResult object at 0x104262e58>
# 680 <pymongo.results.UpdateResult object at 0x10426d948>
# 681 <pymongo.results.UpdateResult object at 0x1042622d0>
# 682 <pymongo.results.UpdateResult object at 0x1042626c0>
# 683 <pymongo.results.UpdateResult object at 0x1042626c0>
# 684 <pymongo.results.UpdateResult object at 0x10425ba68>
# 685 <pymongo.results.UpdateResult object at 0x10425b048>
# 686 <pymongo.results.UpdateResult object at 0x1042695a0>
# 687 <pymongo.results.UpdateResult object at 0x10426dd80>
# 688 <pymongo.results.UpdateResult object at 0x10426df78>
# 689 <pymongo.results.UpdateResult object at 0x10426dc18>
# 690 <pymongo.results.UpdateResult object at 0x104269318>
# 691 <pymongo.results.UpdateResult object at 0x104269fc0>
# 692 <pymongo.results.UpdateResult object at 0x10426d1b0>
# 693 <pymongo.results.UpdateResult object at 0x10426dbd0>
# 694 <pymongo.results.UpdateResult object at 0x104243168>
# 695 <pymongo.results.UpdateResult object at 0x10426ddc8>
# 696 <pymongo.results.UpdateResult object at 0x104262dc8>
# 697 <pymongo.results.UpdateResult object at 0x10427a9d8>
# 698 <pymongo.results.UpdateResult object at 0x10427a048>
# 699 <pymongo.results.UpdateResult object at 0x10427cd80>
# 700 <pymongo.results.UpdateResult object at 0x1042697e0>
# 701 <pymongo.results.UpdateResult object at 0x1042413a8>
# 702 <pymongo.results.UpdateResult object at 0x10427ce10>
# 703 <pymongo.results.UpdateResult object at 0x10427cd80>
# 704 <pymongo.results.UpdateResult object at 0x104241d38>
# 705 <pymongo.results.UpdateResult object at 0x104241cf0>
# 706 <pymongo.results.UpdateResult object at 0x10427c8b8>
# 707 <pymongo.results.UpdateResult object at 0x10427c048>
# 708 <pymongo.results.UpdateResult object at 0x10426db88>
# 709 <pymongo.results.UpdateResult object at 0x10426d240>
# 710 <pymongo.results.UpdateResult object at 0x10426d750>
# 711 <pymongo.results.UpdateResult object at 0x10426dab0>
# 712 <pymongo.results.UpdateResult object at 0x10426d708>
# 713 <pymongo.results.UpdateResult object at 0x10426d048>
# 714 <pymongo.results.UpdateResult object at 0x104241318>
# 715 <pymongo.results.UpdateResult object at 0x10427c828>
# 716 <pymongo.results.UpdateResult object at 0x1042463f0>
# 717 <pymongo.results.UpdateResult object at 0x1042463f0>
# 718 <pymongo.results.UpdateResult object at 0x104246798>
# 719 <pymongo.results.UpdateResult object at 0x1042623f0>
# 720 <pymongo.results.UpdateResult object at 0x10424ea68>
# 721 <pymongo.results.UpdateResult object at 0x1042623f0>
# 722 <pymongo.results.UpdateResult object at 0x1042623f0>
# 723 <pymongo.results.UpdateResult object at 0x10427c558>
# 724 <pymongo.results.UpdateResult object at 0x10424ea68>
# 725 <pymongo.results.UpdateResult object at 0x10427c630>
# 726 <pymongo.results.UpdateResult object at 0x10427c630>
# 727 <pymongo.results.UpdateResult object at 0x104246750>
# 728 <pymongo.results.UpdateResult object at 0x10427c318>
# 729 <pymongo.results.UpdateResult object at 0x10427cd38>
# 730 <pymongo.results.UpdateResult object at 0x1042466c0>
# 731 <pymongo.results.UpdateResult object at 0x1042415a0>
# 732 <pymongo.results.UpdateResult object at 0x1042415a0>
# 733 <pymongo.results.UpdateResult object at 0x104246dc8>
# 734 <pymongo.results.UpdateResult object at 0x10426dd38>
# 735 <pymongo.results.UpdateResult object at 0x10426d360>
# 736 <pymongo.results.UpdateResult object at 0x10426d318>
# 737 <pymongo.results.UpdateResult object at 0x10427c120>
# 738 <pymongo.results.UpdateResult object at 0x10427c7e0>
# 739 <pymongo.results.UpdateResult object at 0x10426da68>
# 740 <pymongo.results.UpdateResult object at 0x10426dcf0>
# 741 <pymongo.results.UpdateResult object at 0x10426d678>
# 742 <pymongo.results.UpdateResult object at 0x10426d4c8>
# 743 <pymongo.results.UpdateResult object at 0x10427c1f8>
# 744 <pymongo.results.UpdateResult object at 0x104246c60>
# 745 <pymongo.results.UpdateResult object at 0x1042461b0>
# 746 <pymongo.results.UpdateResult object at 0x10426dc60>
# 747 <pymongo.results.UpdateResult object at 0x104241288>
# 748 <pymongo.results.UpdateResult object at 0x104243bd0>
# 749 <pymongo.results.UpdateResult object at 0x104243708>
# 750 <pymongo.results.UpdateResult object at 0x104241870>
# 751 <pymongo.results.UpdateResult object at 0x10426dee8>
# 752 <pymongo.results.UpdateResult object at 0x104241798>
# 753 <pymongo.results.UpdateResult object at 0x104246828>
# 754 <pymongo.results.UpdateResult object at 0x104246828>
# 755 <pymongo.results.UpdateResult object at 0x104246708>
# 756 <pymongo.results.UpdateResult object at 0x104246240>
# 757 <pymongo.results.UpdateResult object at 0x104242318>
# 758 <pymongo.results.UpdateResult object at 0x104241900>
# 759 <pymongo.results.UpdateResult object at 0x10427afc0>
# 760 <pymongo.results.UpdateResult object at 0x10426d048>
# 761 <pymongo.results.UpdateResult object at 0x10426dca8>
# 762 <pymongo.results.UpdateResult object at 0x10427afc0>
# 763 <pymongo.results.UpdateResult object at 0x10426d288>
# 764 <pymongo.results.UpdateResult object at 0x104246168>
# 765 <pymongo.results.UpdateResult object at 0x104241a68>
# 766 <pymongo.results.UpdateResult object at 0x10427a798>
# 767 <pymongo.results.UpdateResult object at 0x104241d38>
# 768 <pymongo.results.UpdateResult object at 0x104241ea0>
# 769 <pymongo.results.UpdateResult object at 0x10426d240>
# 770 <pymongo.results.UpdateResult object at 0x10427c5e8>
# 771 <pymongo.results.UpdateResult object at 0x10426db40>
# 772 <pymongo.results.UpdateResult object at 0x10427c750>
# 773 <pymongo.results.UpdateResult object at 0x10427afc0>
# 774 <pymongo.results.UpdateResult object at 0x10427adc8>
# 775 <pymongo.results.UpdateResult object at 0x10427a2d0>
# 776 <pymongo.results.UpdateResult object at 0x10427c1f8>
# 777 <pymongo.results.UpdateResult object at 0x10426d090>
# 778 <pymongo.results.UpdateResult object at 0x10427c558>
# 779 <pymongo.results.UpdateResult object at 0x10427ccf0>
# 780 <pymongo.results.UpdateResult object at 0x104246cf0>
# 781 <pymongo.results.UpdateResult object at 0x104243cf0>
# 782 <pymongo.results.UpdateResult object at 0x104243990>
# 783 <pymongo.results.UpdateResult object at 0x10426dea0>
# 784 <pymongo.results.UpdateResult object at 0x104242360>
# 785 <pymongo.results.UpdateResult object at 0x10427cfc0>
# 786 <pymongo.results.UpdateResult object at 0x10427cab0>
# 787 <pymongo.results.UpdateResult object at 0x10426da20>
# 788 <pymongo.results.UpdateResult object at 0x10426d120>
# 789 <pymongo.results.UpdateResult object at 0x10426d438>
# 790 <pymongo.results.UpdateResult object at 0x104241048>
# 791 <pymongo.results.UpdateResult object at 0x104241ee8>
# 792 <pymongo.results.UpdateResult object at 0x1042695e8>
# 793 <pymongo.results.UpdateResult object at 0x10426dbd0>
# 794 <pymongo.results.UpdateResult object at 0x10425b0d8>
# 795 <pymongo.results.UpdateResult object at 0x10425b798>
# 796 <pymongo.results.UpdateResult object at 0x10426d318>
# 797 <pymongo.results.UpdateResult object at 0x10426d318>
# 798 <pymongo.results.UpdateResult object at 0x10426de58>
# 799 <pymongo.results.UpdateResult object at 0x10426d990>
# 800 <pymongo.results.UpdateResult object at 0x10426d8b8>
# 801 <pymongo.results.UpdateResult object at 0x10425bea0>
# 802 <pymongo.results.UpdateResult object at 0x10425b4c8>
# 803 <pymongo.results.UpdateResult object at 0x104243cf0>
# 804 <pymongo.results.UpdateResult object at 0x104246d38>
# 805 <pymongo.results.UpdateResult object at 0x1042433a8>
# 806 <pymongo.results.UpdateResult object at 0x1042433a8>
# 807 <pymongo.results.UpdateResult object at 0x10427c120>
# 808 <pymongo.results.UpdateResult object at 0x10427ac18>
# 809 <pymongo.results.UpdateResult object at 0x10426d8b8>
# 810 <pymongo.results.UpdateResult object at 0x10427a0d8>
# 811 <pymongo.results.UpdateResult object at 0x1042461f8>
# 812 <pymongo.results.UpdateResult object at 0x1042465a0>
# 813 <pymongo.results.UpdateResult object at 0x10426d3f0>
# 814 <pymongo.results.UpdateResult object at 0x10426d3f0>
# 815 <pymongo.results.UpdateResult object at 0x10427aca8>
# 816 <pymongo.results.UpdateResult object at 0x104242a20>
# 817 <pymongo.results.UpdateResult object at 0x104242708>
# 818 <pymongo.results.UpdateResult object at 0x1042423f0>
# 819 <pymongo.results.UpdateResult object at 0x104241708>
# 820 <pymongo.results.UpdateResult object at 0x10425b5a0>
# 821 <pymongo.results.UpdateResult object at 0x10427f510>
# 822 <pymongo.results.UpdateResult object at 0x104243ee8>
# 823 <pymongo.results.UpdateResult object at 0x104243ee8>
# 824 <pymongo.results.UpdateResult object at 0x104243e10>
# 825 <pymongo.results.UpdateResult object at 0x104243c18>
# 826 <pymongo.results.UpdateResult object at 0x10427c678>
# 827 <pymongo.results.UpdateResult object at 0x10427f120>
# 828 <pymongo.results.UpdateResult object at 0x104243ee8>
# 829 <pymongo.results.UpdateResult object at 0x10427f480>
# 830 <pymongo.results.UpdateResult object at 0x10427c5a0>
# 831 <pymongo.results.UpdateResult object at 0x10427c5a0>
# 832 <pymongo.results.UpdateResult object at 0x104242750>
# 833 <pymongo.results.UpdateResult object at 0x10427a948>
# 834 <pymongo.results.UpdateResult object at 0x104269708>
# 835 <pymongo.results.UpdateResult object at 0x1079c64c8>
# 836 <pymongo.results.UpdateResult object at 0x1042433f0>
# 837 <pymongo.results.UpdateResult object at 0x1042694c8>
# 838 <pymongo.results.UpdateResult object at 0x1042420d8>
# 839 <pymongo.results.UpdateResult object at 0x1042693a8>
# 840 <pymongo.results.UpdateResult object at 0x10427cc18>
# 841 <pymongo.results.UpdateResult object at 0x104243dc8>
# 842 <pymongo.results.UpdateResult object at 0x1042428b8>
# 843 <pymongo.results.UpdateResult object at 0x1042426c0>
# 844 <pymongo.results.UpdateResult object at 0x10427da20>
# ...
# 898 <pymongo.results.UpdateResult object at 0x104243948>
# 899 <pymongo.results.UpdateResult object at 0x10427a900>
# 900 <pymongo.results.UpdateResult object at 0x10427a900>
# 901 <pymongo.results.UpdateResult object at 0x10427d048>
# 902 <pymongo.results.UpdateResult object at 0x10426d3a8>
# 903 <pymongo.results.UpdateResult object at 0x1079bd090>
# 904 <pymongo.results.UpdateResult object at 0x1079c6870>
# 905 <pymongo.results.UpdateResult object at 0x1079bd1f8>
# 906 <pymongo.results.UpdateResult object at 0x1079bd1f8>
# 907 <pymongo.results.UpdateResult object at 0x10427f240>
# 908 <pymongo.results.UpdateResult object at 0x10427f8b8>
# 909 <pymongo.results.UpdateResult object at 0x1079c6558>
# 910 <pymongo.results.UpdateResult object at 0x1079c6798>
# 911 <pymongo.results.UpdateResult object at 0x10427fab0>
# 912 <pymongo.results.UpdateResult object at 0x1079c6a20>
# 913 <pymongo.results.UpdateResult object at 0x1079c6ca8>
# 914 <pymongo.results.UpdateResult object at 0x10425b2d0>
# 915 <pymongo.results.UpdateResult object at 0x10427ab88>
# 916 <pymongo.results.UpdateResult object at 0x10427a708>
# 917 <pymongo.results.UpdateResult object at 0x10427aaf8>
# 918 <pymongo.results.UpdateResult object at 0x10427a708>
# 919 <pymongo.results.UpdateResult object at 0x10425b3f0>
# 920 <pymongo.results.UpdateResult object at 0x10425b288>
# 921 <pymongo.results.UpdateResult object at 0x10427d1f8>
# 922 <pymongo.results.UpdateResult object at 0x10427dbd0>
# 923 <pymongo.results.UpdateResult object at 0x10427af30>
# 924 <pymongo.results.UpdateResult object at 0x10427d510>
# 925 <pymongo.results.UpdateResult object at 0x10427aee8>
# 926 <pymongo.results.UpdateResult object at 0x10427aee8>
# 927 <pymongo.results.UpdateResult object at 0x10427ab40>
# 928 <pymongo.results.UpdateResult object at 0x10427d048>
# 929 <pymongo.results.UpdateResult object at 0x10425f6c0>
# 930 <pymongo.results.UpdateResult object at 0x10425f6c0>
# 931 <pymongo.results.UpdateResult object at 0x10425ff78>
# 932 <pymongo.results.UpdateResult object at 0x10425f438>
# 933 <pymongo.results.UpdateResult object at 0x10425b990>
# 934 <pymongo.results.UpdateResult object at 0x10425b3f0>
# 935 <pymongo.results.UpdateResult object at 0x10425f438>
# 936 <pymongo.results.UpdateResult object at 0x10425fdc8>
# 937 <pymongo.results.UpdateResult object at 0x10425fdc8>
# 938 <pymongo.results.UpdateResult object at 0x10427dc60>
# 939 <pymongo.results.UpdateResult object at 0x1079c69d8>
# 940 <pymongo.results.UpdateResult object at 0x1079c6750>
# 941 <pymongo.results.UpdateResult object at 0x1079c6510>
# 942 <pymongo.results.UpdateResult object at 0x10425b480>
# 943 <pymongo.results.UpdateResult object at 0x10425b558>
# 944 <pymongo.results.UpdateResult object at 0x10425bab0>
# 945 <pymongo.results.UpdateResult object at 0x10425bb88>
# 946 <pymongo.results.UpdateResult object at 0x10425b5e8>
# 947 <pymongo.results.UpdateResult object at 0x10427dbd0>
# 948 <pymongo.results.UpdateResult object at 0x10427d7e0>
# 949 <pymongo.results.UpdateResult object at 0x10427d1b0>
# 950 <pymongo.results.UpdateResult object at 0x10427da20>
# 951 <pymongo.results.UpdateResult object at 0x10427db40>
# 952 <pymongo.results.UpdateResult object at 0x10425f708>
# 953 <pymongo.results.UpdateResult object at 0x10427d090>
# 954 <pymongo.results.UpdateResult object at 0x10427d750>
# 955 <pymongo.results.UpdateResult object at 0x10427daf8>
# 956 <pymongo.results.UpdateResult object at 0x10425f7e0>
# 957 <pymongo.results.UpdateResult object at 0x10427d480>
# 958 <pymongo.results.UpdateResult object at 0x1079bd990>
# 959 <pymongo.results.UpdateResult object at 0x1079bdcf0>
# 960 <pymongo.results.UpdateResult object at 0x1079bd240>
# 961 <pymongo.results.UpdateResult object at 0x1079bd048>
# 962 <pymongo.results.UpdateResult object at 0x1079c6c60>
# 963 <pymongo.results.UpdateResult object at 0x10427a480>
# 964 <pymongo.results.UpdateResult object at 0x10427aea0>
# 965 <pymongo.results.UpdateResult object at 0x10427aaf8>
# 966 <pymongo.results.UpdateResult object at 0x1079bd438>
# 967 <pymongo.results.UpdateResult object at 0x10425fb88>
# 968 <pymongo.results.UpdateResult object at 0x1079bddc8>
# 969 <pymongo.results.UpdateResult object at 0x1079bdf78>
# 970 <pymongo.results.UpdateResult object at 0x10425f3a8>
# 971 <pymongo.results.UpdateResult object at 0x10425f3a8>
# 972 <pymongo.results.UpdateResult object at 0x10425f048>
# 973 <pymongo.results.UpdateResult object at 0x10425f3a8>
# 974 <pymongo.results.UpdateResult object at 0x10427a090>
# 975 <pymongo.results.UpdateResult object at 0x10427a090>
# 976 <pymongo.results.UpdateResult object at 0x10427d0d8>
# 977 <pymongo.results.UpdateResult object at 0x10427d0d8>
# 978 <pymongo.results.UpdateResult object at 0x10427d5a0>
# 979 <pymongo.results.UpdateResult object at 0x1079c6ea0>
# 980 <pymongo.results.UpdateResult object at 0x1079c6ea0>
# 981 <pymongo.results.UpdateResult object at 0x104242090>
# 982 <pymongo.results.UpdateResult object at 0x104242af8>
# 983 <pymongo.results.UpdateResult object at 0x104242ee8>
# 984 <pymongo.results.UpdateResult object at 0x10427f438>
# 985 <pymongo.results.UpdateResult object at 0x10427fab0>
# 986 <pymongo.results.UpdateResult object at 0x10427fa20>
# 987 <pymongo.results.UpdateResult object at 0x1042420d8>
# 988 <pymongo.results.UpdateResult object at 0x104242558>
# 989 <pymongo.results.UpdateResult object at 0x104242990>
# 990 <pymongo.results.UpdateResult object at 0x104242d38>
# 991 <pymongo.results.UpdateResult object at 0x104242f78>
# 992 <pymongo.results.UpdateResult object at 0x10425fb88>
# 993 <pymongo.results.UpdateResult object at 0x104242d80>
# 994 <pymongo.results.UpdateResult object at 0x1042427e0>
# 995 <pymongo.results.UpdateResult object at 0x104242948>
# 996 <pymongo.results.UpdateResult object at 0x1079bda68>
# 997 <pymongo.results.UpdateResult object at 0x10425f750>
# 998 <pymongo.results.UpdateResult object at 0x10425f8b8>
# 999 <pymongo.results.UpdateResult object at 0x10427aa20>
# 1000 <pymongo.results.UpdateResult object at 0x10427a480>
# 1001 <pymongo.results.UpdateResult object at 0x10425fa68>
# 1002 <pymongo.results.UpdateResult object at 0x1079bd9d8>
# 1003 <pymongo.results.UpdateResult object at 0x10427fb88>
# 1004 <pymongo.results.UpdateResult object at 0x104243828>
# 1005 <pymongo.results.UpdateResult object at 0x104243678>
# 1006 <pymongo.results.UpdateResult object at 0x104243510>
# 1007 <pymongo.results.UpdateResult object at 0x1079bd480>
# 1008 <pymongo.results.UpdateResult object at 0x1079bd168>
# 1009 <pymongo.results.UpdateResult object at 0x1042430d8>
# 1010 <pymongo.results.UpdateResult object at 0x104243ea0>
# 1011 <pymongo.results.UpdateResult object at 0x104243630>
# 1012 <pymongo.results.UpdateResult object at 0x10427ad38>
# 1013 <pymongo.results.UpdateResult object at 0x104243120>
# 1014 <pymongo.results.UpdateResult object at 0x104241ab0>
# 1015 <pymongo.results.UpdateResult object at 0x10427cd80>
# 1016 <pymongo.results.UpdateResult object at 0x104241510>
# 1017 <pymongo.results.UpdateResult object at 0x104241990>
# 1018 <pymongo.results.UpdateResult object at 0x10427c4c8>
# 1019 <pymongo.results.UpdateResult object at 0x104243168>
# 1020 <pymongo.results.UpdateResult object at 0x104241288>
# 1021 <pymongo.results.UpdateResult object at 0x104241cf0>
# 1022 <pymongo.results.UpdateResult object at 0x10425b900>
# 1023 <pymongo.results.UpdateResult object at 0x104246900>
# 1024 <pymongo.results.UpdateResult object at 0x104246900>
# 1025 <pymongo.results.UpdateResult object at 0x1079bd9d8>
# 1026 <pymongo.results.UpdateResult object at 0x10425bab0>
# 1027 <pymongo.results.UpdateResult object at 0x10427a8b8>
# 1028 <pymongo.results.UpdateResult object at 0x1079c68b8>
# 1029 <pymongo.results.UpdateResult object at 0x104246a20>
# 1030 <pymongo.results.UpdateResult object at 0x10425fd38>
# 1031 <pymongo.results.UpdateResult object at 0x104246a20>
# 1032 <pymongo.results.UpdateResult object at 0x10427a318>
# 1033 <pymongo.results.UpdateResult object at 0x10427d798>
# 1034 <pymongo.results.UpdateResult object at 0x10425f360>
# 1035 <pymongo.results.UpdateResult object at 0x10427dd80>
# 1036 <pymongo.results.UpdateResult object at 0x10425f828>
# 1037 <pymongo.results.UpdateResult object at 0x10427a438>
# 1038 <pymongo.results.UpdateResult object at 0x10427d948>
# 1039 <pymongo.results.UpdateResult object at 0x1079c6240>
# 1040 <pymongo.results.UpdateResult object at 0x104241288>
# 1041 <pymongo.results.UpdateResult object at 0x104241870>
# 1042 <pymongo.results.UpdateResult object at 0x104241e58>
# 1043 <pymongo.results.UpdateResult object at 0x104241e58>
# 1044 <pymongo.results.UpdateResult object at 0x1042413f0>
# 1045 <pymongo.results.UpdateResult object at 0x10427c168>
# 1046 <pymongo.results.UpdateResult object at 0x10427c6c0>
# 1047 <pymongo.results.UpdateResult object at 0x1079c61f8>
# 1048 <pymongo.results.UpdateResult object at 0x1079c61f8>
# 1049 <pymongo.results.UpdateResult object at 0x10427f4c8>
# 1050 <pymongo.results.UpdateResult object at 0x1079bd048>
# 1051 <pymongo.results.UpdateResult object at 0x10427f438>
# 1052 <pymongo.results.UpdateResult object at 0x1079bbdc8>
# 1053 <pymongo.results.UpdateResult object at 0x104243828>
# 1054 <pymongo.results.UpdateResult object at 0x10427dca8>
# 1055 <pymongo.results.UpdateResult object at 0x10427af78>
# 1056 <pymongo.results.UpdateResult object at 0x1079c6d38>
# 1057 <pymongo.results.UpdateResult object at 0x1079c6d38>
# 1058 <pymongo.results.UpdateResult object at 0x10427aa20>
# 1059 <pymongo.results.UpdateResult object at 0x10427aab0>
# 1060 <pymongo.results.UpdateResult object at 0x10427c3a8>
# 1061 <pymongo.results.UpdateResult object at 0x1079c6c60>
# 1062 <pymongo.results.UpdateResult object at 0x1079c6c60>
# 1063 <pymongo.results.UpdateResult object at 0x1079c6f30>
# 1064 <pymongo.results.UpdateResult object at 0x10427a360>
# 1065 <pymongo.results.UpdateResult object at 0x104269a68>
# 1066 <pymongo.results.UpdateResult object at 0x10427d8b8>
# 1067 <pymongo.results.UpdateResult object at 0x10427c048>
# 1068 <pymongo.results.UpdateResult object at 0x10427f318>
# 1069 <pymongo.results.UpdateResult object at 0x10427ca20>
# 1070 <pymongo.results.UpdateResult object at 0x1079bd3a8>
# 1071 <pymongo.results.UpdateResult object at 0x1079c6af8>
# 1072 <pymongo.results.UpdateResult object at 0x1079bddc8>
# 1073 <pymongo.results.UpdateResult object at 0x10425f2d0>
# 1074 <pymongo.results.UpdateResult object at 0x10427ca68>
# 1075 <pymongo.results.UpdateResult object at 0x10427cc60>
# 1076 <pymongo.results.UpdateResult object at 0x10427f168>
# 1077 <pymongo.results.UpdateResult object at 0x1079c6870>
# 1078 <pymongo.results.UpdateResult object at 0x1079c6870>
# 1079 <pymongo.results.UpdateResult object at 0x1079c6ee8>
# 1080 <pymongo.results.UpdateResult object at 0x10427cc60>
# 1081 <pymongo.results.UpdateResult object at 0x104246ab0>
# 1082 <pymongo.results.UpdateResult object at 0x10427faf8>
# 1083 <pymongo.results.UpdateResult object at 0x104246af8>
# 1084 <pymongo.results.UpdateResult object at 0x10425be10>
# 1085 <pymongo.results.UpdateResult object at 0x10427ffc0>
# 1086 <pymongo.results.UpdateResult object at 0x10425b7e0>
# 1087 <pymongo.results.UpdateResult object at 0x1079bbf30>
# 1088 <pymongo.results.UpdateResult object at 0x104242d80>
# 1089 <pymongo.results.UpdateResult object at 0x1079d0240>
# 1090 <pymongo.results.UpdateResult object at 0x1079d0288>
# 1091 <pymongo.results.UpdateResult object at 0x1079bbdc8>
# 1092 <pymongo.results.UpdateResult object at 0x104242cf0>
# 1093 <pymongo.results.UpdateResult object at 0x1079d0678>
# 1094 <pymongo.results.UpdateResult object at 0x104242fc0>
# 1095 <pymongo.results.UpdateResult object at 0x104246318>
# 1096 <pymongo.results.UpdateResult object at 0x10425b318>
# 1097 <pymongo.results.UpdateResult object at 0x104246ca8>
# 1098 <pymongo.results.UpdateResult object at 0x1042465e8>
# 1099 <pymongo.results.UpdateResult object at 0x104246d38>
# 1100 <pymongo.results.UpdateResult object at 0x10427d948>
# 1101 <pymongo.results.UpdateResult object at 0x10427d948>
# 1102 <pymongo.results.UpdateResult object at 0x10427d168>
# 1103 <pymongo.results.UpdateResult object at 0x104246f78>
# 1104 <pymongo.results.UpdateResult object at 0x1042421f8>
# 1105 <pymongo.results.UpdateResult object at 0x104246948>
# 1106 <pymongo.results.UpdateResult object at 0x10425bc18>
# 1107 <pymongo.results.UpdateResult object at 0x10425b2d0>
# 1108 <pymongo.results.UpdateResult object at 0x10425bb40>
# 1109 <pymongo.results.UpdateResult object at 0x1079c2a68>
# 1110 <pymongo.results.UpdateResult object at 0x104242168>
# 1111 <pymongo.results.UpdateResult object at 0x10425bc60>
# 1112 <pymongo.results.UpdateResult object at 0x1042423a8>
# 1113 <pymongo.results.UpdateResult object at 0x1042423a8>
# 1114 <pymongo.results.UpdateResult object at 0x104242a20>
# 1115 <pymongo.results.UpdateResult object at 0x104246d80>
# 1116 <pymongo.results.UpdateResult object at 0x104269a68>
# 1117 <pymongo.results.UpdateResult object at 0x104242a20>
# 1118 <pymongo.results.UpdateResult object at 0x1042421b0>
# 1119 <pymongo.results.UpdateResult object at 0x104242f78>
# 1120 <pymongo.results.UpdateResult object at 0x104242708>
# 1121 <pymongo.results.UpdateResult object at 0x104242750>
# 1122 <pymongo.results.UpdateResult object at 0x10427d870>
# 1123 <pymongo.results.UpdateResult object at 0x10427d5a0>
# 1124 <pymongo.results.UpdateResult object at 0x1042691f8>
# 1125 <pymongo.results.UpdateResult object at 0x104269a68>
# 1126 <pymongo.results.UpdateResult object at 0x104246438>
# 1127 <pymongo.results.UpdateResult object at 0x1042464c8>
# 1128 <pymongo.results.UpdateResult object at 0x104246120>
# 1129 <pymongo.results.UpdateResult object at 0x1042693a8>
# 1130 <pymongo.results.UpdateResult object at 0x104242750>
# 1131 <pymongo.results.UpdateResult object at 0x104242750>
# 1132 <pymongo.results.UpdateResult object at 0x1079d0ea0>
# 1133 <pymongo.results.UpdateResult object at 0x1079d0ea0>
# 1134 <pymongo.results.UpdateResult object at 0x1079d0870>
# 1135 <pymongo.results.UpdateResult object at 0x104269a20>
# 1136 <pymongo.results.UpdateResult object at 0x10427de58>
# 1137 <pymongo.results.UpdateResult object at 0x104269b88>
# 1138 <pymongo.results.UpdateResult object at 0x104269ca8>
# 1139 <pymongo.results.UpdateResult object at 0x1079d0b88>
# 1140 <pymongo.results.UpdateResult object at 0x1042464c8>
# 1141 <pymongo.results.UpdateResult object at 0x1079d0708>
# 1142 <pymongo.results.UpdateResult object at 0x1042692d0>
# 1143 <pymongo.results.UpdateResult object at 0x1079d0708>
# 1144 <pymongo.results.UpdateResult object at 0x104269828>
# 1145 <pymongo.results.UpdateResult object at 0x1079bbe58>
# 1146 <pymongo.results.UpdateResult object at 0x10425b438>
# 1147 <pymongo.results.UpdateResult object at 0x10425b9d8>
# 1148 <pymongo.results.UpdateResult object at 0x10425bdc8>
# 1149 <pymongo.results.UpdateResult object at 0x10425be58>
# 1150 <pymongo.results.UpdateResult object at 0x104242120>
# 1151 <pymongo.results.UpdateResult object at 0x1079d03f0>
# 1152 <pymongo.results.UpdateResult object at 0x104246678>
# 1153 <pymongo.results.UpdateResult object at 0x10427d3a8>
# 1154 <pymongo.results.UpdateResult object at 0x10427d510>
# 1155 <pymongo.results.UpdateResult object at 0x104246798>
# 1156 <pymongo.results.UpdateResult object at 0x1079bbc60>
# 1157 <pymongo.results.UpdateResult object at 0x1079bbb40>
# 1158 <pymongo.results.UpdateResult object at 0x1042693f0>
# 1159 <pymongo.results.UpdateResult object at 0x10427c1b0>
# 1160 <pymongo.results.UpdateResult object at 0x10427cd80>
# 1161 <pymongo.results.UpdateResult object at 0x104246750>
# 1162 <pymongo.results.UpdateResult object at 0x10427c3a8>
# 1163 <pymongo.results.UpdateResult object at 0x10427c6c0>
# 1164 <pymongo.results.UpdateResult object at 0x10425fab0>
# 1165 <pymongo.results.UpdateResult object at 0x10427ca20>
# 1166 <pymongo.results.UpdateResult object at 0x104242438>
# 1167 <pymongo.results.UpdateResult object at 0x104242cf0>
# 1168 <pymongo.results.UpdateResult object at 0x10427c3f0>
# 1169 <pymongo.results.UpdateResult object at 0x10427c3f0>
# 1170 <pymongo.results.UpdateResult object at 0x10425bcf0>
# 1171 <pymongo.results.UpdateResult object at 0x10427c2d0>
# 1172 <pymongo.results.UpdateResult object at 0x104242558>
# 1173 <pymongo.results.UpdateResult object at 0x1042438b8>
# 1174 <pymongo.results.UpdateResult object at 0x104242ea0>

# %% [markdown]
# # Example
# Here's an example of a single record and the information we are able to assemble when we have a DOI and it responds with metadata via content negotiation.

# %%
exampleRecord = collection_rrl.find_one({"$and":[{"Link Metadata":{"$exists":True}},{"url":{"$exists":True}},{"Link Metadata.Success":True}]})

print (exampleRecord["Citation String"])

display (exampleRecord["Link Metadata"]["Link Response"])
# Out:
# Apa, A.D., Thompson, T.R., and Reese, K.P., 2017, Juvenile greater sage-grouse survival, movements, and recruitment in Colorado: Journal of Wildlife Management, v. 81, no. 4, p. 652–668.
# {'DOI': '10.1002/jwmg.21230',
#  'ISSN': ['0022-541X'],
#  'URL': 'http://dx.doi.org/10.1002/jwmg.21230',
#  'author': [{'affiliation': [{'name': 'Colorado Division of Parks and Wildlife; 711 Independent Avenue Grand Junction CO 81505'}],
#    'family': 'Apa',
#    'given': 'Anthony D.',
#    'sequence': 'first'},
#   {'affiliation': [{'name': 'Department of Fish and Wildlife Sciences; University of Idaho; P. O. Box 441136 Moscow ID 83844 USA'}],
#    'family': 'Thompson',
#    'given': 'Thomas R.',
#    'sequence': 'additional'},
#   {'affiliation': [{'name': 'Department of Fish and Wildlife Sciences; University of Idaho; P. O. Box 441136 Moscow ID 83844 USA'}],
#    'family': 'Reese',
#    'given': 'Kerry P.',
#    'sequence': 'additional'}],
#  'container-title': 'The Journal of Wildlife Management',
#  'container-title-short': 'Jour. Wild. Mgmt.',
#  'content-domain': {'crossmark-restriction': False, 'domain': []},
#  'created': {'date-parts': [[2017, 4, 7]],
#   'date-time': '2017-04-07T10:33:27Z',
#   'timestamp': 1491561207000},
#  'deposited': {'date-parts': [[2017, 4, 25]],
#   'date-time': '2017-04-25T11:11:54Z',
#   'timestamp': 1493118714000},
#  'funder': [{'DOI': '10.13039/100007430',
#    'award': [],
#    'doi-asserted-by': 'publisher',
#    'name': 'National Fish and Wildlife Foundation'},
#   {'award': [], 'name': 'Colorado Division of Parks and Wildlife'},
#   {'award': [], 'name': 'University of Idaho'}],
#  'indexed': {'date-parts': [[2018, 5, 9]],
#   'date-time': '2018-05-09T10:51:28Z',
#   'timestamp': 1525863088162},
#  'is-referenced-by-count': 1,
#  'issue': '4',
#  'issued': {'date-parts': [[2017, 4, 7]]},
#  'journal-issue': {'issue': '4',
#   'published-print': {'date-parts': [[2017, 5]]}},
#  'language': 'en',
#  'license': [{'URL': 'http://doi.wiley.com/10.1002/tdm_license_1',
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'start': {'date-parts': [[2017, 4, 7]],
#     'date-time': '2017-04-07T00:00:00Z',
#     'timestamp': 1491523200000}},
#   {'URL': 'http://onlinelibrary.wiley.com/termsAndConditions',
#    'content-version': 'vor',
#    'delay-in-days': 0,
#    'start': {'date-parts': [[2017, 4, 7]],
#     'date-time': '2017-04-07T00:00:00Z',
#     'timestamp': 1491523200000}}],
#  'link': [{'URL': 'https://api.wiley.com/onlinelibrary/tdm/v1/articles/10.1002%2Fjwmg.21230',
#    'content-type': 'application/pdf',
#    'content-version': 'vor',
#    'intended-application': 'text-mining'},
#   {'URL': 'http://onlinelibrary.wiley.com/wol1/doi/10.1002/jwmg.21230/fullpdf',
#    'content-type': 'unspecified',
#    'content-version': 'vor',
#    'intended-application': 'similarity-checking'}],
#  'member': '311',
#  'original-title': [],
#  'page': '652-668',
#  'prefix': '10.1002',
#  'published-online': {'date-parts': [[2017, 4, 7]]},
#  'published-print': {'date-parts': [[2017, 5]]},
#  'publisher': 'Wiley',
#  'reference': [{'DOI': '10.1890/05-1871',
#    'article-title': 'Linking occurrence and fitness to persistence: habitat-based approach for endangered greater sage-grouse',
#    'author': 'Aldridge',
#    'doi-asserted-by': 'publisher',
#    'first-page': '508',
#    'journal-title': 'Ecological Applications',
#    'key': '10.1002/jwmg.21230-BIB0001|jwmg21230-cit-0001',
#    'volume': '17',
#    'year': '2007'},
#   {'DOI': '10.1007/978-0-387-74075-1',
#    'author': 'Anderson',
#    'doi-asserted-by': 'publisher',
#    'key': '10.1002/jwmg.21230-BIB0002|jwmg21230-cit-0002',
#    'volume-title': 'Model based inferences in the life sciences',
#    'year': '2008'},
#   {'DOI': '10.2193/2008-177',
#    'article-title': 'Survival rates of female greater sage-grouse in autumn and winter in southeastern Oregon',
#    'author': 'Anthony',
#    'doi-asserted-by': 'publisher',
#    'first-page': '538',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0003|jwmg21230-cit-0003',
#    'volume': '73',
#    'year': '2009'},
#   {'DOI': '10.1002/zoo.21228',
#    'article-title': 'Captive-rearing of Gunnison sage-grouse from egg collection to adulthood to foster proactive conservation and recovery of a conservation-reliant species',
#    'author': 'Apa',
#    'doi-asserted-by': 'publisher',
#    'first-page': '438',
#    'journal-title': 'Zoo Biology',
#    'key': '10.1002/jwmg.21230-BIB0004|jwmg21230-cit-0004',
#    'volume': '34',
#    'year': '2015'},
#   {'DOI': '10.1002/zoo.21253',
#    'article-title': 'Captive-breeding of captive and wild-reared Gunnison sage-grouse',
#    'author': 'Apa',
#    'doi-asserted-by': 'publisher',
#    'first-page': '70',
#    'journal-title': 'Zoo Biology',
#    'key': '10.1002/jwmg.21230-BIB0005|jwmg21230-cit-0005',
#    'volume': '35',
#    'year': '2016'},
#   {'article-title': 'Impact of strip spray on vegetation and sage grouse use on summer habitat',
#    'author': 'Autenrieth',
#    'first-page': '147',
#    'journal-title': 'Proceedings of the Western States Sage Grouse Workshop',
#    'key': '10.1002/jwmg.21230-BIB0006|jwmg21230-cit-0006',
#    'volume': '6',
#    'year': '1969'},
#   {'key': '10.1002/jwmg.21230-BIB0007|jwmg21230-cit-0007',
#    'unstructured': 'Bartazzo , A. M. 2007'},
#   {'DOI': '10.2193/0091-7648(2006)34[1070:MASOJG]2.0.CO;2',
#    'article-title': 'Movements and survival of juvenile greater sage-grouse in southeastern Idaho',
#    'author': 'Beck',
#    'doi-asserted-by': 'publisher',
#    'first-page': '1070',
#    'journal-title': 'Wildlife Society Bulletin',
#    'key': '10.1002/jwmg.21230-BIB0008|jwmg21230-cit-0008',
#    'volume': '34',
#    'year': '2006'},
#   {'DOI': '10.2307/1367928',
#    'article-title': 'Weights of Colorado sage grouse',
#    'author': 'Beck',
#    'doi-asserted-by': 'publisher',
#    'first-page': '241',
#    'journal-title': 'Condor',
#    'key': '10.1002/jwmg.21230-BIB0009|jwmg21230-cit-0009',
#    'volume': '80',
#    'year': '1978'},
#   {'author': 'Bergerud',
#    'key': '10.1002/jwmg.21230-BIB0010|jwmg21230-cit-0010',
#    'volume-title': 'Adaptive strategies and population ecology of northern grouse',
#    'year': '1988'},
#   {'article-title': 'Permutation techniques based on Euclidean analysis spaces: a new and powerful statistical method for ecological research',
#    'author': 'Biondini',
#    'first-page': '155',
#    'journal-title': 'Coenoses',
#    'key': '10.1002/jwmg.21230-BIB0011|jwmg21230-cit-0011',
#    'volume': '3',
#    'year': '1988'},
#   {'DOI': '10.2307/3800087',
#    'article-title': 'Brood break-up, dispersal, mobility, and mortality of juvenile prairie chickens',
#    'author': 'Bowman',
#    'doi-asserted-by': 'publisher',
#    'first-page': '27',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0012|jwmg21230-cit-0012',
#    'volume': '41',
#    'year': '1977'},
#   {'article-title': 'Guidelines for maintenance of sage grouse habitats',
#    'author': 'Braun',
#    'first-page': '99',
#    'journal-title': 'Wildlife Society Bulletin',
#    'key': '10.1002/jwmg.21230-BIB0013|jwmg21230-cit-0013',
#    'volume': '5',
#    'year': '1977'},
#   {'key': '10.1002/jwmg.21230-BIB0014|jwmg21230-cit-0014',
#    'unstructured': 'Braun , C. E. D. M. Hoffman 1979'},
#   {'article-title': 'Attachment of radiotransmitters to one-day-old sage grouse chicks',
#    'author': 'Burkepile',
#    'first-page': '93',
#    'journal-title': 'Wildlife Society Bulletin',
#    'key': '10.1002/jwmg.21230-BIB0015|jwmg21230-cit-0015',
#    'volume': '30',
#    'year': '2002'},
#   {'author': 'Burnham',
#    'key': '10.1002/jwmg.21230-BIB0016|jwmg21230-cit-0016',
#    'volume-title': 'Model selection and multi-model inferences: a practical information-theoretic approach',
#    'year': '2002'},
#   {'DOI': '10.1890/14-1639.1',
#    'article-title': 'Model averaging and muddled multimodel inferences',
#    'author': 'Cade',
#    'doi-asserted-by': 'publisher',
#    'first-page': '2370',
#    'journal-title': 'Ecology',
#    'key': '10.1002/jwmg.21230-BIB0017|jwmg21230-cit-0017',
#    'volume': '96',
#    'year': '2015'},
#   {'key': '10.1002/jwmg.21230-BIB0018|jwmg21230-cit-0018',
#    'unstructured': 'Cade , B. S. J. D. Richards 2001'},
#   {'article-title': 'Survival of black grouse Tetrao tetrix in the French Alps',
#    'author': 'Caizergues',
#    'first-page': '177',
#    'journal-title': 'Wildlife Biology',
#    'key': '10.1002/jwmg.21230-BIB0019|jwmg21230-cit-0019',
#    'volume': '3',
#    'year': '1997'},
#   {'DOI': '10.2307/3802497',
#    'article-title': 'Passive integrated transponders and patagial tag markers for northern bobwhite chicks',
#    'author': 'Carver',
#    'doi-asserted-by': 'publisher',
#    'first-page': '162',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0020|jwmg21230-cit-0020',
#    'volume': '63',
#    'year': '1999'},
#   {'author': 'Caswell',
#    'key': '10.1002/jwmg.21230-BIB0021|jwmg21230-cit-0021',
#    'volume-title': 'Matrix population models: construction, analysis, and interpretation',
#    'year': '2001'},
#   {'DOI': '10.1002/jwmg.724',
#    'article-title': 'Greater sage-grouse survival in Utah',
#    'author': 'Caudill',
#    'doi-asserted-by': 'publisher',
#    'first-page': '808',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0022|jwmg21230-cit-0022',
#    'volume': '78',
#    'year': '2014'},
#   {'DOI': '10.2307/5542',
#    'article-title': 'Directions in conservation biology',
#    'author': 'Caughley',
#    'doi-asserted-by': 'publisher',
#    'first-page': '215',
#    'journal-title': 'Journal of Animal Ecology',
#    'key': '10.1002/jwmg.21230-BIB0023|jwmg21230-cit-0023',
#    'volume': '63',
#    'year': '1994'},
#   {'DOI': '10.2307/2265583',
#    'article-title': 'Annual variation in survival and breeding probability in greater flamingos',
#    'author': 'Cézilly',
#    'doi-asserted-by': 'publisher',
#    'first-page': '1143',
#    'journal-title': 'Ecology',
#    'key': '10.1002/jwmg.21230-BIB0024|jwmg21230-cit-0024',
#    'volume': '77',
#    'year': '1996'},
#   {'DOI': '10.1016/0040-5809(86)90024-9',
#    'article-title': 'The evolutionary advantages of group foraging',
#    'author': 'Clark',
#    'doi-asserted-by': 'publisher',
#    'first-page': '45',
#    'journal-title': 'Theoretical Population Biology',
#    'key': '10.1002/jwmg.21230-BIB0025|jwmg21230-cit-0025',
#    'volume': '30',
#    'year': '1986'},
#   {'key': '10.1002/jwmg.21230-BIB0026|jwmg21230-cit-0026',
#    'unstructured': 'Connelly , J. W. S. T. Knick M. A. Schroeder S. J. Stiver 2004'},
#   {'author': 'Connelly',
#    'key': '10.1002/jwmg.21230-BIB0027|jwmg21230-cit-0027',
#    'volume-title': 'Greater sage-grouse and sagebrush: ecology and conservation of a landscape species and its habitats. Studies in Avian Biology Volume 38',
#    'year': '2011'},
#   {'article-title': 'Guidelines for management of sage grouse populations and habitat',
#    'author': 'Connelly',
#    'first-page': '967',
#    'journal-title': 'Wildlife Society Bulletin',
#    'key': '10.1002/jwmg.21230-BIB0028|jwmg21230-cit-0028',
#    'volume': '28',
#    'year': '2000'},
#   {'DOI': '10.2307/3798498',
#    'article-title': 'Age and sex of sage grouse from wings',
#    'author': 'Cruden',
#    'doi-asserted-by': 'publisher',
#    'first-page': '846',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0029|jwmg21230-cit-0029',
#    'volume': '27',
#    'year': '1963'},
#   {'DOI': '10.2193/2006-454',
#    'article-title': 'Greater sage-grouse winter habitat selection and energy development',
#    'author': 'Doherty',
#    'doi-asserted-by': 'publisher',
#    'first-page': '187',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0030|jwmg21230-cit-0030',
#    'volume': '72',
#    'year': '2008'},
#   {'DOI': '10.1111/j.1600-0587.2012.07348.x',
#    'article-title': 'Collinearity: a review of methods to deal with it and a simulation study evaluating their performance',
#    'author': 'Dormann',
#    'doi-asserted-by': 'publisher',
#    'first-page': '27',
#    'journal-title': 'Ecography',
#    'key': '10.1002/jwmg.21230-BIB0031|jwmg21230-cit-0031',
#    'volume': '36',
#    'year': '2013'},
#   {'DOI': '10.2307/3796862',
#    'article-title': 'A method for obtaining sage grouse age and sex ratios from wings',
#    'author': 'Eng',
#    'doi-asserted-by': 'publisher',
#    'first-page': '267',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0032|jwmg21230-cit-0032',
#    'volume': '19',
#    'year': '1955'},
#   {'DOI': '10.1002/jwmg.894',
#    'article-title': 'MMI: multimodal inference or models with management implications',
#    'author': 'Fieberg',
#    'doi-asserted-by': 'publisher',
#    'first-page': '708',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0033|jwmg21230-cit-0033',
#    'volume': '79',
#    'year': '2015'},
#   {'article-title': 'Methods for trapping sage grouse in Colorado',
#    'author': 'Giesen',
#    'first-page': '224',
#    'journal-title': 'Wildlife Society Bulletin',
#    'key': '10.1002/jwmg.21230-BIB0034|jwmg21230-cit-0034',
#    'volume': '10',
#    'year': '1982'},
#   {'DOI': '10.2307/3799385',
#    'article-title': 'Brood break-up and dispersal of ruffed grouse',
#    'author': 'Godfrey',
#    'doi-asserted-by': 'publisher',
#    'first-page': '609',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0035|jwmg21230-cit-0035',
#    'volume': '33',
#    'year': '1969'},
#   {'DOI': '10.2193/2007-410',
#    'article-title': 'Survival of greater sage-grouse chicks and broods in the northern Great Basin',
#    'author': 'Gregg',
#    'doi-asserted-by': 'publisher',
#    'first-page': '904',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0036|jwmg21230-cit-0036',
#    'volume': '73',
#    'year': '2009'},
#   {'DOI': '10.1111/j.1469-7998.2006.00159.x',
#    'article-title': 'Ecology of juvenile grouse during the transition to adulthood',
#    'author': 'Hannon',
#    'doi-asserted-by': 'publisher',
#    'first-page': '422',
#    'journal-title': 'Journal of Zoology',
#    'key': '10.1002/jwmg.21230-BIB0037|jwmg21230-cit-0037',
#    'volume': '269',
#    'year': '2006'},
#   {'key': '10.1002/jwmg.21230-BIB0038|jwmg21230-cit-0038',
#    'unstructured': 'Hausleitner , D. 2003'},
#   {'author': 'Herman-Brunson',
#    'key': '10.1002/jwmg.21230-BIB0039|jwmg21230-cit-0039',
#    'volume-title': 'Nesting and brood-rearing habitat selection of greater sage-grouse and associated survival of hens and broods at the edge of their historic distribution. Thesis',
#    'year': '2007'},
#   {'DOI': '10.2307/1367751',
#    'article-title': 'Survival and reproduction of dispersing blue grouse',
#    'author': 'Hines',
#    'doi-asserted-by': 'publisher',
#    'first-page': '43',
#    'journal-title': 'Condor',
#    'key': '10.1002/jwmg.21230-BIB0040|jwmg21230-cit-0040',
#    'volume': '88',
#    'year': '1986'},
#   {'DOI': '10.1650/7749.1',
#    'article-title': 'Spatial distribution of greater sage-grouse nest in relatively contiguous habitats',
#    'author': 'Holloran',
#    'doi-asserted-by': 'publisher',
#    'first-page': '742',
#    'journal-title': 'Condor',
#    'key': '10.1002/jwmg.21230-BIB0041|jwmg21230-cit-0041',
#    'volume': '107',
#    'year': '2005'},
#   {'DOI': '10.2307/3799390',
#    'article-title': 'Sage grouse nesting and brood habitat in Idaho',
#    'author': 'Klebenow',
#    'doi-asserted-by': 'publisher',
#    'first-page': '649',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0042|jwmg21230-cit-0042',
#    'volume': '33',
#    'year': '1969'},
#   {'key': '10.1002/jwmg.21230-BIB0043|jwmg21230-cit-0043',
#    'unstructured': 'Knick , S. T. J. W. Connelly 2011'},
#   {'author': 'Kutner',
#    'key': '10.1002/jwmg.21230-BIB0044|jwmg21230-cit-0044',
#    'volume-title': 'Applied linear statistical models',
#    'year': '2004'},
#   {'DOI': '10.1126/science.3420403',
#    'article-title': 'Genetics and demography in biological conservation',
#    'author': 'Lande',
#    'doi-asserted-by': 'publisher',
#    'first-page': '1455',
#    'journal-title': 'Science',
#    'key': '10.1002/jwmg.21230-BIB0045|jwmg21230-cit-0045',
#    'volume': '241',
#    'year': '1988'},
#   {'key': '10.1002/jwmg.21230-BIB0046|jwmg21230-cit-0046',
#    'unstructured': 'Mielke , P. W. K. J. Berry 1982 11 1197 1207'},
#   {'key': '10.1002/jwmg.21230-BIB0047|jwmg21230-cit-0047',
#    'unstructured': 'Moynahan , B. J. 2004 Centrocercus urophasianus'},
#   {'DOI': '10.2193/0022-541X(2006)70[1530:OITSE]2.0.CO;2',
#    'article-title': 'On improving telemetry-based survival estimation',
#    'author': 'Murray',
#    'doi-asserted-by': 'publisher',
#    'first-page': '1530',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0048|jwmg21230-cit-0048',
#    'volume': '70',
#    'year': '2006'},
#   {'article-title': 'Brood break-up and juvenile dispersal of lesser prairie-chickens in Kansas',
#    'author': 'Pitman',
#    'first-page': '85',
#    'journal-title': 'Prairie Naturalist',
#    'key': '10.1002/jwmg.21230-BIB0049|jwmg21230-cit-0049',
#    'volume': '38',
#    'year': '2006'},
#   {'DOI': '10.1002/jwmg.787',
#    'article-title': 'Eastern wild turkey demography: sensitivity of vital rates between landscapes',
#    'author': 'Pollentier',
#    'doi-asserted-by': 'publisher',
#    'first-page': '1372',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0050|jwmg21230-cit-0050',
#    'volume': '78',
#    'year': '2014'},
#   {'DOI': '10.2307/3801296',
#    'article-title': 'Survival analysis in telemetry studies: the staggered entry design',
#    'author': 'Pollock',
#    'doi-asserted-by': 'publisher',
#    'first-page': '7',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0051|jwmg21230-cit-0051',
#    'volume': '53',
#    'year': '1989'},
#   {'DOI': '10.2307/3796582',
#    'article-title': 'Identification of waterfowl nest predators',
#    'author': 'Rearden',
#    'doi-asserted-by': 'publisher',
#    'first-page': '386',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0052|jwmg21230-cit-0052',
#    'volume': '15',
#    'year': '1951'},
#   {'DOI': '10.2307/3801395',
#    'article-title': 'Sage grouse food selection in winter, North Park, Colorado',
#    'author': 'Remington',
#    'doi-asserted-by': 'publisher',
#    'first-page': '1055',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0053|jwmg21230-cit-0053',
#    'volume': '49',
#    'year': '1985'},
#   {'DOI': '10.1139/z86-004',
#    'article-title': 'The fall phase of dispersal in juvenile spruce grouse',
#    'author': 'Schroeder',
#    'doi-asserted-by': 'publisher',
#    'first-page': '16',
#    'journal-title': 'Canadian Journal of Zoology',
#    'key': '10.1002/jwmg.21230-BIB0054|jwmg21230-cit-0054',
#    'volume': '64',
#    'year': '1986'},
#   {'DOI': '10.2307/1370144',
#    'article-title': 'Unusually high reproductive effort by sage grouse in a fragmented habitat in north-central Washington',
#    'author': 'Schroeder',
#    'doi-asserted-by': 'publisher',
#    'first-page': '933',
#    'journal-title': 'Condor',
#    'key': '10.1002/jwmg.21230-BIB0055|jwmg21230-cit-0055',
#    'volume': '99',
#    'year': '1997'},
#   {'article-title': 'Predation and the management of prairie grouse',
#    'author': 'Schroeder',
#    'first-page': '24',
#    'journal-title': 'Wildlife Society Bulletin',
#    'key': '10.1002/jwmg.21230-BIB0056|jwmg21230-cit-0056',
#    'volume': '29',
#    'year': '2001'},
#   {'DOI': '10.1650/7425',
#    'article-title': 'Distribution of sage-grouse in North America',
#    'author': 'Schroeder',
#    'doi-asserted-by': 'publisher',
#    'first-page': '363',
#    'journal-title': 'Condor',
#    'key': '10.1002/jwmg.21230-BIB0057|jwmg21230-cit-0057',
#    'volume': '106',
#    'year': '2004'},
#   {'DOI': '10.2307/3808983',
#    'article-title': 'Predation and hunting mortality of ruffed grouse in central Wisconsin',
#    'author': 'Small',
#    'doi-asserted-by': 'publisher',
#    'first-page': '512',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0058|jwmg21230-cit-0058',
#    'volume': '55',
#    'year': '1991'},
#   {'article-title': 'Are ruffed grouse more vulnerable to mortality during dispersal',
#    'author': 'Small',
#    'first-page': '2020',
#    'journal-title': 'Ecology',
#    'key': '10.1002/jwmg.21230-BIB0059|jwmg21230-cit-0059',
#    'volume': '74',
#    'year': '1993'},
#   {'DOI': '10.1016/j.biocon.2007.10.018',
#    'article-title': 'Polygyny and female breeding failure reduce effective population size in the lekking Gunnison sage-grouse',
#    'author': 'Stiver',
#    'doi-asserted-by': 'publisher',
#    'first-page': '472',
#    'journal-title': 'Biological Conservation',
#    'key': '10.1002/jwmg.21230-BIB0060|jwmg21230-cit-0060',
#    'volume': '141',
#    'year': '2008'},
#   {'article-title': 'Is the hazel grouse a poor disperser',
#    'author': 'Swenson',
#    'first-page': '347',
#    'journal-title': 'Transactions of the Congress of the International Union of Game Biologists',
#    'key': '10.1002/jwmg.21230-BIB0061|jwmg21230-cit-0061',
#    'volume': '20',
#    'year': '1991'},
#   {'DOI': '10.2307/3677206',
#    'article-title': 'Factors shaping winter social organization in hazel grouse Bonasa bonasia: a comparative study in the eastern and western Palearctic',
#    'author': 'Swenson',
#    'doi-asserted-by': 'publisher',
#    'first-page': '4',
#    'journal-title': 'Journal of Avian Biology',
#    'key': '10.1002/jwmg.21230-BIB0062|jwmg21230-cit-0062',
#    'volume': '26',
#    'year': '1995'},
#   {'DOI': '10.1002/jwmg.267',
#    'article-title': 'Managing multiple vital rates to maximize greater sage-grouse population growth',
#    'author': 'Taylor',
#    'doi-asserted-by': 'publisher',
#    'first-page': '336',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0063|jwmg21230-cit-0063',
#    'volume': '76',
#    'year': '2012'},
#   {'key': '10.1002/jwmg.21230-BIB0064|jwmg21230-cit-0064',
#    'unstructured': 'Thompson , T. R. 2012'},
#   {'DOI': '10.1002/jwmg.905',
#    'article-title': 'Captive rearing sage-grouse for augmentation of surrogate wild broods: evidence for success',
#    'author': 'Thompson',
#    'doi-asserted-by': 'publisher',
#    'first-page': '998',
#    'journal-title': 'Journal of Wildlife Management',
#    'key': '10.1002/jwmg.21230-BIB0065|jwmg21230-cit-0065',
#    'volume': '79',
#    'year': '2015'},
#   {'key': '10.1002/jwmg.21230-BIB0066|jwmg21230-cit-0066',
#    'unstructured': '1978'},
#   {'article-title': 'An improved spotlighting technique for capturing sage grouse',
#    'author': 'Wakkinen',
#    'first-page': '425',
#    'journal-title': 'Wildlife Society Bulletin',
#    'key': '10.1002/jwmg.21230-BIB0067|jwmg21230-cit-0067',
#    'volume': '20',
#    'year': '1992'},
#   {'key': '10.1002/jwmg.21230-BIB0068|jwmg21230-cit-0068',
#    'unstructured': 'Walker , B. L. 2008'},
#   {'article-title': 'Dispersal, survival, and causes of mortality in black grouse Tetrao tetrix in northern England',
#    'author': 'Warren',
#    'first-page': '91',
#    'journal-title': 'Wildlife Biology',
#    'key': '10.1002/jwmg.21230-BIB0069|jwmg21230-cit-0069',
#    'volume': '8',
#    'year': '2002'},
#   {'key': '10.1002/jwmg.21230-BIB0070|jwmg21230-cit-0070',
#    'unstructured': '2003 http://www.wrcc.dri.edu'},
#   {'DOI': '10.1080/00063659909477239',
#    'article-title': 'Program MARK: survival estimation from populations of marked animals',
#    'author': 'White',
#    'doi-asserted-by': 'publisher',
#    'first-page': '120',
#    'issue': 'Supplement',
#    'journal-title': 'Bird Study',
#    'key': '10.1002/jwmg.21230-BIB0071|jwmg21230-cit-0071',
#    'volume': '46',
#    'year': '1999'},
#   {'author': 'White',
#    'key': '10.1002/jwmg.21230-BIB0072|jwmg21230-cit-0072',
#    'volume-title': 'Analysis of wildlife radio-tracking data',
#    'year': '1990'},
#   {'key': '10.1002/jwmg.21230-BIB0073|jwmg21230-cit-0073',
#    'unstructured': 'Wik , P. A. 2002'},
#   {'DOI': '10.1890/03-0038',
#    'article-title': 'Population dynamics across geographical ranges: time-series analyses of three small game species',
#    'author': 'Williams',
#    'doi-asserted-by': 'publisher',
#    'first-page': '2654',
#    'journal-title': 'Ecology',
#    'key': '10.1002/jwmg.21230-BIB0074|jwmg21230-cit-0074',
#    'volume': '84',
#    'year': '2003'},
#   {'author': 'Winterstein',
#    'key': '10.1002/jwmg.21230-BIB0075|jwmg21230-cit-0075',
#    'volume-title': 'Radio-tracking and animal populations',
#    'year': '2001'},
#   {'key': '10.1002/jwmg.21230-BIB0076|jwmg21230-cit-0076',
#    'unstructured': 'Yoder , J. M. 2004'},
#   {'DOI': '10.1093/beheco/arh037',
#    'article-title': 'The cost of dispersal: predation as a function of movement and site familiarity in ruffed grouse',
#    'author': 'Yoder',
#    'doi-asserted-by': 'publisher',
#    'first-page': '469',
#    'journal-title': 'Behavioral Ecology',
#    'key': '10.1002/jwmg.21230-BIB0077|jwmg21230-cit-0077',
#    'volume': '15',
#    'year': '2004'}],
#  'reference-count': 77,
#  'references-count': 77,
#  'relation': {'cites': []},
#  'score': 1.0,
#  'short-title': [],
#  'source': 'Crossref',
#  'subtitle': ['Juvenile Sage-Grouse Survival and Recruitment'],
#  'title': 'Juvenile greater sage-grouse survival, movements, and recruitment in Colorado',
#  'type': 'article-journal',
#  'volume': '81'}
